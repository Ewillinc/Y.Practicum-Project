# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# ### Features:

# %% [markdown]
# * **DateCrawled** - дата скачивания анкеты из базы
# * **VehicleType** - тип автомобиля кузова
# * **RegistrationYear**- год регистрации автомобиля
# * **Gearbox** - тип коробки передач
# * **Power** - мощность
# * **Model** - модель автомобиля
# * **Kilometer** - пробег
# * **RegistrationMonth** - месяц регистрации автомобиля
# * **FuelType** - тип кузова
# * **Brand** - марка автомобиля
# * **Repaired** - была ли машина в ремонте или нет
# * **DateCreated** - дата создания анкеты
# * **NumberOfPictures** - количество фотографий автомобиля
# * **PostalCode** - почтовый индекс владельца анкеты(пользователя)
# * **LastSeen** - дата последней активности пользователя

# %% [markdown]
# ### Train:

# %% [markdown]
# **Price** - цена

# %% [markdown]
# ## Осмотр и подготовка данных

# %% [markdown]
# ### Импорт библиотек:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

from  sklearn.preprocessing import OrdinalEncoder
# from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import GridSearchCV
from math import sqrt



from catboost import CatBoostRegressor, Pool
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression


plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-dark.mplstyle')
plt.rcParams.update({'font.size': 12})

import time

# %% [markdown]
# ### Загрузка данных

# %%
dt = pd.read_csv('/datasets/autos.csv')

# %% [markdown]
# ## Общий осмотр данных

# %% [markdown]
# ### describe

# %%
display(dt.head(3), dt.describe(), 'Размерность датасета:',dt.shape)
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0   golf     150000                  0    petrol  volkswagen      NaN
# 1    NaN     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep      NaN
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
#                Price  RegistrationYear          Power      Kilometer  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000
# 'Размерность датасета:'
# (354369, 16)

# %% [markdown]
# ### int-columns Histogram

# %%
dt.hist(figsize = [14,14], color = 'gold', alpha = 1,bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'RegistrationYear'}>,
#         <AxesSubplot:title={'center':'Power'}>],
#        [<AxesSubplot:title={'center':'Kilometer'}>,
#         <AxesSubplot:title={'center':'RegistrationMonth'}>,
#         <AxesSubplot:title={'center':'NumberOfPictures'}>],
#        [<AxesSubplot:title={'center':'PostalCode'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Подсчет нулей:

# %%
dt.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Kilometer                0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# Repaired             71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %% [markdown]
# ### Дубликаты

# %%
dt.duplicated().sum()
# Out:
# 4

# %%
dt[dt.duplicated() == True]
# Out:
#                 DateCrawled  Price VehicleType  RegistrationYear Gearbox  \
# 171088  2016-03-08 18:42:48   1799       coupe              1999    auto
# 231258  2016-03-28 00:56:10   1000       small              2002  manual
# 258109  2016-04-03 09:01:15   4699       coupe              2003    auto
# 325651  2016-03-18 18:46:15   1999       wagon              2001  manual
#
#         Power   Model  Kilometer  RegistrationMonth  FuelType          Brand  \
# 171088    193     clk      20000                  7    petrol  mercedes_benz
# 231258     83   other     150000                  1    petrol         suzuki
# 258109    218     clk     125000                  6    petrol  mercedes_benz
# 325651    131  passat     150000                  7  gasoline     volkswagen
#
#        Repaired          DateCreated  NumberOfPictures  PostalCode  \
# 171088       no  2016-03-08 00:00:00                 0       89518
# 231258       no  2016-03-28 00:00:00                 0       66589
# 258109      yes  2016-04-03 00:00:00                 0       75196
# 325651       no  2016-03-18 00:00:00                 0       36391
#
#                    LastSeen
# 171088  2016-03-09 09:46:57
# 231258  2016-03-28 08:46:21
# 258109  2016-04-07 09:44:54
# 325651  2016-03-18 18:46:15

# %%
dt_without = dt.drop(columns = ['PostalCode'])

# %%
dt_without.duplicated().sum()
# Out:
# 5

# %% [markdown]
# ### Максимумы уникальных значений:

# %%
dt_columns = [k for k in dt.columns]
for k in range(len(dt_columns)):
    display(dt[dt_columns[k]].value_counts().sort_values(ascending = False).head(5))
# Out:
# 2016-03-24 14:49:47    7
# 2016-03-26 22:57:31    6
# 2016-03-19 21:49:56    6
# 2016-04-01 19:25:23    5
# 2016-03-05 14:44:30    5
# Name: DateCrawled, dtype: int64
# 0       10772
# 500      5670
# 1500     5394
# 1000     4649
# 1200     4594
# Name: Price, dtype: int64
# sedan          91457
# small          79831
# wagon          65166
# bus            28775
# convertible    20203
# Name: VehicleType, dtype: int64
# 2000    24490
# 1999    22728
# 2005    22109
# 2001    20124
# 2006    19900
# Name: RegistrationYear, dtype: int64
# manual    268251
# auto       66285
# Name: Gearbox, dtype: int64
# 0      40225
# 75     24023
# 60     15897
# 150    14590
# 101    13298
# Name: Power, dtype: int64
# golf     29232
# other    24421
# 3er      19761
# polo     13066
# corsa    12570
# Name: Model, dtype: int64
# 150000    238209
# 125000     36454
# 100000     14882
# 90000      11567
# 80000      10047
# Name: Kilometer, dtype: int64
# 0    37352
# 3    34373
# 6    31508
# 4    29270
# 5    29153
# Name: RegistrationMonth, dtype: int64
# petrol      216352
# gasoline     98720
# lpg           5310
# cng            565
# hybrid         233
# Name: FuelType, dtype: int64
# volkswagen       77013
# opel             39931
# bmw              36914
# mercedes_benz    32046
# audi             29456
# Name: Brand, dtype: int64
# no     247161
# yes     36054
# Name: Repaired, dtype: int64
# 2016-04-03 00:00:00    13719
# 2016-04-04 00:00:00    13317
# 2016-03-20 00:00:00    12918
# 2016-03-12 00:00:00    12840
# 2016-03-21 00:00:00    12691
# Name: DateCreated, dtype: int64
# 0    354369
# Name: NumberOfPictures, dtype: int64
# 10115    819
# 65428    613
# 66333    343
# 32257    317
# 44145    317
# Name: PostalCode, dtype: int64
# 2016-04-06 13:45:54    17
# 2016-04-07 09:44:27    16
# 2016-04-06 08:46:30    16
# 2016-04-06 09:17:58    16
# 2016-04-07 05:44:30    16
# Name: LastSeen, dtype: int64

# %% [markdown]
# ## Индивидуальный осмотр:

# %% [markdown]
# ### Обработка столбцов отображающих даты:

# %%
# еще раз взгляним на столбцы признаков
dt.head(2)
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
#
#   Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0  golf     150000                  0    petrol  volkswagen      NaN
# 1   NaN     125000                  5  gasoline        audi      yes
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50

# %% [markdown]
# * DateCrewled - дата скачивания анкеты из бызы
# * RegistrationYear - год регистрации автомобиля
# * RegistrationMonth - месяц регистрации автомобиля
# * DateCreated - дата создания анкеты
# * LastSeen - дата последне активности пользователя

# %% [markdown]
# Из столбцов выше можно утверддительно предположить:
# 1. LastSeen - признак будущего времени, кторый  может показать срок продажи авто, а не его стоимость
# 2. DateCrewled - признак будущего времени, которой не связан с ценой автомобила
# 3. DateCreated - признак не влияющий на цену автомобиля
#
# Что можно сделать?
# * Без уникального id пользователя, предполагая, что LastSeen - последний день его активности по этой анкете, можно вывести возраст автомобиля в момент его продажи. (DateCreated менее показателен для машин, которые не продались в первое время по стартовой цене. Т.е. он не учитывает динамику изменения цены в отсутствии спроса на предложение продавца):
# 1. С использованием LastSeen & RegistrationYear+RegistrationMonth - выведем возраст автомобиля
# 2. Впоследствии удалить признаки будущего времени: DateCrewled, DateCreated, LastSeen.  Признаки, которые преобразуются в возарст автомобиля: RegistrationMonth , RegistrationYear

# %%
# приводим столбец к виду datetime
dt['LastSeen'] = pd.to_datetime(dt['LastSeen'])

# %%
# создаем столбцы с датой и месяцем продажи:
dt['sale_year'] = pd.DatetimeIndex(dt['LastSeen']).year
dt['sale_month'] = pd.DatetimeIndex(dt['LastSeen']).month

# %% [markdown]
# **Удаление выбросов**

# %% [markdown]
# **Год регистрации:**

# %%
sns.boxplot(data = dt['RegistrationYear'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Cмотрим максимальный\минимальный год закрытия заказа:

# %%
print(dt['sale_year'].max())
print(dt['sale_year'].min())
# Out:
# 2016
# 2016

# %% [markdown]
# отсекаем верхний предел регистрации автомобиля:

# %%
dt = dt.query('RegistrationYear < 2017')
sns.boxplot(data = dt['RegistrationYear'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ограничим нижний порог автомобилей:

# %%
for i in range(1950,2000,5):
    print('Год:',i, 'Количество авто:',dt[dt['RegistrationYear'] < i].shape[0])
# Out:
# Год: 1950 Количество авто: 246
# Год: 1955 Количество авто: 310
# Год: 1960 Количество авто: 422
# Год: 1965 Количество авто: 818
# Год: 1970 Количество авто: 1338
# Год: 1975 Количество авто: 2393
# Год: 1980 Количество авто: 3452
# Год: 1985 Количество авто: 5448
# Год: 1990 Количество авто: 9669
# Год: 1995 Количество авто: 26518

# %%
dt = dt.query('RegistrationYear > 1970')

# %%
sns.boxplot(data = dt['RegistrationYear'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Месяц регистрации автомобиля:**

# %%
sns.boxplot(data = dt['RegistrationMonth'])
print(len(dt['RegistrationMonth'].unique()))
# Out:
# 13

# %% [markdown]
# Просмотр аномального столбца, с нулевым месяцем:

# %%
display(dt[dt['RegistrationMonth'] == 0].head(3))
print('Количество нулей:',dt[dt['RegistrationMonth'] == 0].shape[0])
# Out:
#             DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0   2016-03-24 11:52:17    480         NaN              1993  manual      0
# 9   2016-03-17 10:53:50    999       small              1998  manual    101
# 16  2016-04-01 12:46:46    300         NaN              2016     NaN     60
#
#    Model  Kilometer  RegistrationMonth FuelType       Brand Repaired  \
# 0   golf     150000                  0   petrol  volkswagen      NaN
# 9   golf     150000                  0      NaN  volkswagen      NaN
# 16  polo     150000                  0   petrol  volkswagen      NaN
#
#             DateCreated  NumberOfPictures  PostalCode            LastSeen  \
# 0   2016-03-24 00:00:00                 0       70435 2016-04-07 03:16:57
# 9   2016-03-17 00:00:00                 0       27472 2016-03-31 17:17:06
# 16  2016-04-01 00:00:00                 0       38871 2016-04-01 12:46:46
#
#     sale_year  sale_month
# 0        2016           4
# 9        2016           3
# 16       2016           4
# Количество нулей: 33143

# %% [markdown]
# Предположим: подобное значени заполнялось в связи с незнанием или нежеланием заполнять месяц, что не является выбросом.

# %%
dt['RegistrationMonth'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Не хочется увеличивать значение конкретного значения на 30.000 образцов, но с учётом будущего обращения всех столбцов date в единый показатель возраста машины, состоящего из количества месяцев-возраста, для уменьшения дисперсии возраста - вольём их в 6'ой месяц.

# %%
#созраним показатель неизменённого месяца, для подстраховки части значений в будущем показателе
dt['rm'] = dt['RegistrationMonth']

# %%
dt.loc[dt['RegistrationMonth'] == 0, 'RegistrationMonth'] = 6

# %% [markdown]
# **Создание нового столбца**

# %%
# посчитаем взраст машины в месяцах 
dt['age'] =   ((dt['sale_year'] - dt['RegistrationYear']) * 12) + (dt['sale_month'] - dt['RegistrationMonth'])

# %% [markdown]
# **Обработка отклонений**

# %%
# смотрим количество машин с отрицательным возрастом:
(dt['age'] < 0).sum()
# Out:
# 7786

# %% [markdown]
# Часть этих значений появилась вследствии заполнения нулевого месяца значением 6. Исправим эту ситуацию:

# %%
#  проверим, строки в образовании которых виноваты мы rm == 0 and age < 0
dt.loc[(dt['rm'] == 0)&(dt['age'] <0), 'RegistrationMonth'].shape[0]
# Out:
# 2753

# %%
# визуальный осмотр данных с отрицательным годом
dt.loc[dt["age"] < 0].head(3)
# Out:
#             DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 16  2016-04-01 12:46:46    300         NaN              2016     NaN     60
# 31  2016-03-29 16:57:02    899         NaN              2016  manual     60
# 35  2016-03-08 07:54:46    350         NaN              2016  manual     75
#
#    Model  Kilometer  RegistrationMonth FuelType       Brand Repaired  \
# 16  polo     150000                  6   petrol  volkswagen      NaN
# 31  clio     150000                  6   petrol     renault      NaN
# 35  golf     150000                  4   petrol  volkswagen       no
#
#             DateCreated  NumberOfPictures  PostalCode            LastSeen  \
# 16  2016-04-01 00:00:00                 0       38871 2016-04-01 12:46:46
# 31  2016-03-29 00:00:00                 0       37075 2016-03-29 17:43:07
# 35  2016-03-08 00:00:00                 0       19386 2016-03-08 09:44:50
#
#     sale_year  sale_month  rm  age
# 16       2016           4   0   -2
# 31       2016           3   6   -3
# 35       2016           3   4   -1

# %%
# удалим данные с отрицательным возрастом машин:
dt = dt.query('age > 0')

# %%
dt['age'].plot(kind = 'hist', bins = 80, alpha = 0.5, color = 'r', figsize = [20,11])
plt.xlabel('Возраст машины в месяцах', fontsize = 20)
plt.ylabel('Частота', fontsize = 20)
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Удаление столбцов**

# %%
c = ['DateCrawled','RegistrationYear','RegistrationMonth'
                            ,'DateCreated','LastSeen','rm','sale_year','sale_month']
dt_drop_columns = dt.loc[:,c]
dt = dt.drop(columns = c)

# %% [markdown]
# ### Price

# %%
dt['Price'].plot(kind = 'hist', bins = 100, color = 'gold')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
for i in range(0,301,50):
    print('Значений меньше или равно',i,':',dt[dt['Price'] <= i].shape[0])
# Out:
# Значений меньше или равно 0 : 9257
# Значений меньше или равно 50 : 11004
# Значений меньше или равно 100 : 12451
# Значений меньше или равно 150 : 14436
# Значений меньше или равно 200 : 17042
# Значений меньше или равно 250 : 19495
# Значений меньше или равно 300 : 22809

# %%
for i in range(10000,20001,2000):
    print('Значений больше или равно',i,':',dt[dt['Price'] >= i].shape[0])
# Out:
# Значений больше или равно 10000 : 42609
# Значений больше или равно 12000 : 30178
# Значений больше или равно 14000 : 19485
# Значений больше или равно 16000 : 11130
# Значений больше или равно 18000 : 4950
# Значений больше или равно 20000 : 252

# %%
dt[dt['Price'] == 20000].tail(4)
# Out:
#         Price VehicleType Gearbox  Power     Model  Kilometer  FuelType  \
# 342303  20000       sedan  manual    194  insignia      60000  gasoline
# 348208  20000       sedan    auto    241    lancer      40000    petrol
# 349230  20000         bus    auto    204     viano     125000  gasoline
# 354045  20000       coupe    auto    476     other     125000    petrol
#
#                 Brand Repaired  NumberOfPictures  PostalCode  age
# 342303           opel       no                 0       76698   30
# 348208     mitsubishi       no                 0       97737   62
# 349230  mercedes_benz       no                 0       55232   99
# 354045  mercedes_benz       no                 0       38118  116

# %%
dt[dt['Price'] < 10].head(4)
# Out:
#     Price VehicleType Gearbox  Power     Model  Kilometer  FuelType  \
# 7       0       sedan  manual     50     other      40000    petrol
# 40      0         NaN     NaN      0     corsa     150000    petrol
# 59      1         suv  manual    286       NaN     150000       NaN
# 89      1       sedan  manual    113  e_klasse     150000  gasoline
#
#              Brand Repaired  NumberOfPictures  PostalCode  age
# 7       volkswagen       no                 0       19348  428
# 40            opel      NaN                 0       56412  314
# 59  sonstige_autos      NaN                 0       53721  257
# 89   mercedes_benz       no                 0       40589  252

# %% [markdown]
# Машины дешевле 100$ смотрятся крайне сомнительно. Возможно продажа идёт в формате аукциона, но даже так сложно оправдать нулевую цену.
#
# Для сохранения объема данных - не будем сильно урезать края, темболее верх может совпадать с реальной картиной вещей.

# %%
dt = dt.query('Price > 100')

# %% [markdown]
# ### VehicleType

# %%
dt['VehicleType'].value_counts().plot(kind = 'bar', color = 'orange', figsize = [7,5])
# Out:
# <AxesSubplot:>

# %%
dt['VehicleType'].isna().sum()
# Out:
# 10729

# %% [markdown]
# Значений достаточно много,чтобы расскидывать их в конкретные параметры.
#
#
# Пропуски будут заменены переменной 'Unknow' с предположения, что отсутствие данного параметра может повлиять на цену

# %%
dt.loc[dt['VehicleType'].isna()== True, 'VehicleType'] = 'unkonw'

# %% [markdown]
# ### Gearbox

# %%
dt['Gearbox'].value_counts().plot(kind = 'bar', color = 'orange',figsize = [7,5])
# Out:
# <AxesSubplot:>

# %%
dt['Gearbox'].isna().sum()
# Out:
# 12968

# %% [markdown]
# Пропуски заменены переменной - указателем на отсутствиие информации по пункту.

# %%
dt.loc[dt['Gearbox'].isna()== True, 'Gearbox'] = 'unkonw'

# %% [markdown]
# ### **Power**

# %%
sns.boxplot(data = dt['Power'])
# Out:
# <AxesSubplot:>

# %%
dt['Power'].isna().sum()
# Out:
# 0

# %%
dt[dt['Power'] == 0].shape[0]
# Out:
# 28483

# %% [markdown]
# Огромное число нулей и ракетные мощности.
#
# * Заменим нули и выдающиеся значения средними показателями по каждой марке автомобиля

# %%
dt.loc[dt['Power'] == 0,'Repaired'].value_counts()
# Out:
# no     11094
# yes     3395
# Name: Repaired, dtype: int64

# %%
"""По модели можно предсказать бренд, 
а без бренда - нельзя предсказать модель. 
Нам важно знать, что слияние столбцов без модели даст NaN,
а без бренда не останется. Тогда не нужна предварительная обработка""" 
dt['Brand'].isna().sum()
# Out:
# 0

# %%
# сольём модель + бренд
dt['BM'] = dt['Brand'] + '_' + dt['Model']
# добавим новый столбец с группировкой мощности двигателя по модели
dt['Power_means'] = dt.groupby('BM')['Power'].transform('mean')

# %%
dt.loc[dt['Power'] > 700, 'Power'] = dt.loc[dt['Power'] > 700, 'Power_means']
dt.loc[dt['Power'] < 20, 'Power'] = dt.loc[dt['Power'] < 20, 'Power_means']
dt.loc[dt['Power'].isna()==True, 'Power'] = dt.loc[dt['Power'].isna() == True, 'Power_means']

# %%
sns.boxplot(data = dt['Power'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посмотрим оставшиеся нули:

# %%
dt['Power'].isna().sum()
# Out:
# 3666

# %%
dt[dt['Power'].isna() == True].head(2)
# Out:
#      Price VehicleType Gearbox  Power Model  Kilometer FuelType       Brand  \
# 160    500       small  manual    NaN   NaN     150000   petrol     renault
# 260    450      unkonw  manual    NaN   NaN     150000   petrol  mitsubishi
#
#     Repaired  NumberOfPictures  PostalCode  age   BM  Power_means
# 160       no                 0       26969  202  NaN          NaN
# 260       no                 0       59302    1  NaN          NaN

# %% [markdown]
# удалим значения с отсутствием марки:

# %%
dt = dt.dropna(subset = ['Power'])
dt['Power'].isna().sum()
# Out:
# 0

# %%
# Посмотрим тип данных на последок
dt['Power'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Изменим тип данных в переменной:

# %%
dt['Power'] = dt['Power'].astype(int)

# %% [markdown]
# ###  Model

# %%
dt['Model'].isna().sum()
# Out:
# 9912

# %% [markdown]
# в целом, неизвестные модели можно прировнять общему для всех виду: other

# %%
dt.loc[dt['Model'].isna()== True, 'Model'] = 'other'

# %% [markdown]
# ### Kilometer

# %%
dt['Kilometer'].plot(kind = 'hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(data = dt['Kilometer'], color = 'pink')
# Out:
# <AxesSubplot:>

# %%
dt['Kilometer'].describe()
# Out:
# count    313619.000000
# mean     128574.337014
# std       36785.314787
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: Kilometer, dtype: float64

# %%
dt['Kilometer'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### **FuelType**

# %%
dt['FuelType'].value_counts().plot(kind = 'bar', color = 'teal')
# Out:
# <AxesSubplot:>

# %%
dt['FuelType'] = dt['FuelType'].replace({'gasoline':'petrol', 'lpg':'gas','cng':'gas'})

# %% [markdown]
# * gasoline и petrol - бензин,
# * a lpg & cng - газ

# %%
dt['FuelType'].value_counts().plot(kind = 'bar', color = 'teal')
# Out:
# <AxesSubplot:>

# %%
dt['FuelType'].isna().sum()
# Out:
# 17797

# %% [markdown]
# Замена аналогичная VehicleType & Gearbox

# %%
dt.loc[dt['FuelType'].isna()== True, 'FuelType'] = 'unkonw'

# %% [markdown]
# ### Brand

# %% [markdown]
# gasoline и petrol - бензин,
# a lpg & cng - газ

# %%
dt['Brand'].unique()
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'seat', 'honda',
#        'fiat', 'opel', 'mini', 'smart', 'hyundai', 'alfa_romeo', 'subaru',
#        'volvo', 'mitsubishi', 'kia', 'suzuki', 'lancia', 'citroen',
#        'toyota', 'chevrolet', 'dacia', 'daihatsu', 'chrysler',
#        'sonstige_autos', 'jaguar', 'daewoo', 'rover', 'porsche', 'saab',
#        'land_rover', 'trabant', 'lada'], dtype=object)

# %%
dt['Brand'].value_counts().sort_values(ascending = False).plot(kind = 'bar', figsize = [13,9], color = 'tan')
# Out:
# <AxesSubplot:>

# %%
dt['Brand'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Repaired

# %%
dt['Repaired'].value_counts().plot(kind = 'bar', color = ['tomato','goldenrod'])
# Out:
# <AxesSubplot:>

# %%
dt['Repaired'].isna().sum()
# Out:
# 51600

# %% [markdown]
# Присвоим такому большому количеств пропусков статус: 'Неизвестный'

# %%
dt.loc[dt['Repaired'].isna() == True, 'Repaired'] = 'unknow'

# %% [markdown]
# ### Number Of Pictures

# %%
dt['NumberOfPictures'].value_counts().plot(kind = 'bar', color = 'gray')
# Out:
# <AxesSubplot:>

# %%
dt[dt['NumberOfPictures'] > 0]
# Out:
# Empty DataFrame
# Columns: [Price, VehicleType, Gearbox, Power, Model, Kilometer, FuelType, Brand, Repaired, NumberOfPictures, PostalCode, age, BM, Power_means]
# Index: []

# %% [markdown]
# Абсолютное отсутствие изображений

# %%
dt_drop_columns['NumberOfPictures'] = dt['NumberOfPictures']

# %%
dt = dt.drop(columns = ['NumberOfPictures','BM','Power_means'])

# %% [markdown]
# ### PostalCode

# %% [markdown]
# переменная связанная с регионом - возможно, будет доставлять лишний шум

# %%
len(dt['PostalCode'].unique())
# Out:
# 8119

# %%
dt['PostalCode'].isna().sum()
# Out:
# 0

# %% [markdown]
# Изменим тип данныx, чтобы потом закодировать в меньшие значения:

# %%
dt['PostalCode'] = dt['PostalCode'].astype(object)

# %% [markdown]
# ### Итоговый осмотр:

# %% [markdown]
# **Гистограмы действительно количественных значений:**

# %%
dt.hist(figsize = [14,11], bins = 40, color = ['wheat'])
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'Power'}>],
#        [<AxesSubplot:title={'center':'Kilometer'}>,
#         <AxesSubplot:title={'center':'age'}>]], dtype=object)

# %% [markdown]
# **Корреляция числовых признаков:**

# %%
sns.heatmap(dt.corr(), annot = True, cmap ='crest', linewidths = 3, linecolor = 'black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Осмотрим значения категориальных столбцов:**

# %%
object_col = ['VehicleType', 'Gearbox', 'Model', 'FuelType', 'Brand', 'Repaired']
color = ['gold','orange', 'brown', 'purple', 'lightblue']
for i,c in zip(object_col, color):
    print('Top10',i,':')
    
    dt[i].value_counts().sort_values(ascending = False).head(10).plot(kind = 'bar', color = [c], figsize = [9,4])
    
    plt.show()
# Out:
# Top10 VehicleType :
# Top10 Gearbox :
# Top10 Model :
# Top10 FuelType :
# Top10 Brand :

# %% [markdown]
# **Нули:**

# %%
dt.isna().sum()
# Out:
# Price          0
# VehicleType    0
# Gearbox        0
# Power          0
# Model          0
# Kilometer      0
# FuelType       0
# Brand          0
# Repaired       0
# PostalCode     0
# age            0
# dtype: int64

# %%
dt = dt.reset_index()

# %% [markdown]
# ## Подготовка данных к работе с моделями (Кодирование и стандартизация):

# %% [markdown]
# **В данном разделе будут закодированы категориальные столбцы и, с расчетем на дальнейший градиентный спуск - стандартизированы данные**

# %% [markdown]
# **Разобьем DataFrame на категориальные и числовые прризнаки**

# %%
obj_col = ['VehicleType', 'Gearbox', 'Model', 'FuelType', 'Brand', 'Repaired','PostalCode']
int_col = ['Power','Kilometer','age']

# %%
dt_obj,dt_int,dt_obj_full = dt.loc[:,obj_col],dt.loc[:,int_col],dt.loc[:,obj_col]

# %%
dt_target = dt['Price']

# %%
dt_features = dt.drop(columns = ['Price'], axis = 1)

# %% [markdown]
# ### **Train test split**

# %% [markdown]
# Выборка для дерева:
# * Trian Ordinal Encoder
# * Valid Ordinal Encoder
# * Test Ordinal Encoder
#
# Выборка дла бустинга:
# * Train STD(int)
# * Valid STD(int)
# * Test STD(int)

# %%
x_train, x_next, y_train, y_next = train_test_split(dt_features, dt_target, train_size = 0.65, random_state = 1667)

x_valid, x_test, y_valid, y_test = train_test_split(x_next, y_next, train_size = 0.5, random_state = 1667)

# %%
print(x_train.shape, x_valid.shape, x_test.shape)
# Out:
# (203852, 11) (54883, 11) (54884, 11)

# %%
xt_train_int, xt_train_obj = x_train.loc[:,int_col], x_train.loc[:, obj_col]
xt_valid_int, xt_valid_obj = x_valid.loc[:,int_col], x_valid.loc[:, obj_col]
xt_test_int, xt_test_obj   = x_test.loc[:,int_col], x_test.loc[:, obj_col]

# %%
xs_train_int, xs_train_obj = x_train.loc[:,int_col], x_train.loc[:, obj_col]
xs_valid_int, xs_valid_obj = x_valid.loc[:,int_col], x_valid.loc[:, obj_col]
xs_test_int, xs_test_obj   = x_test.loc[:,int_col], x_test.loc[:, obj_col]

# %% [markdown]
# ### **OrdinalEncoder:**

# %%
ordenc = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value = 9999 ) #handle_unknown = 'use_encoded_value', unknown_value = 3

# %%
ordenc.fit(xt_train_obj)
xt_train_obj = pd.DataFrame(ordenc.transform(xt_train_obj), index = xt_train_int.index)
xt_valid_obj = pd.DataFrame(ordenc.transform(xt_valid_obj), index = xt_valid_int.index)
xt_test_obj  = pd.DataFrame(ordenc.transform(xt_test_obj),  index = xt_test_int.index)

# %% [markdown]
# ### **StandartScaler:**

# %%
stdsc = StandardScaler()

# %%
stdsc.fit(xs_train_int)
xs_train_int = pd.DataFrame(stdsc.transform(xs_train_int), index = xs_train_obj.index)
xs_valid_int = pd.DataFrame(stdsc.transform(xs_valid_int),index = xs_valid_obj.index)
xs_test_int  = pd.DataFrame(stdsc.transform(xs_test_int),index = xs_test_obj.index)

# %% [markdown]
# ### **Объединение трансформированных выборок:**

# %% [markdown]
# #### **Для решающего дерева**

# %%
xt_train = pd.merge(xt_train_int, xt_train_obj, left_index = True, right_index = True)
xt_valid = pd.merge(xt_valid_int, xt_valid_obj, left_index = True, right_index = True)
xt_test  = pd.merge(xt_test_int, xt_test_obj,   left_index = True, right_index = True)

# %% [markdown]
# #### **Для бустинга**

# %%
xs_train = xs_train_int.join(xs_train_obj)
xs_valid = xs_valid_int.join(xs_valid_obj)
xs_test  = xs_test_int.join(xs_test_obj)

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### RandomForestRegressor

# %%
best_model = None
best_result = 10000
best_est = 0
best_depth = 0

for est in [25, 50, 100]:
    for depth in [None,2,4,6]:
        rfr = RandomForestRegressor(random_state = 1667, n_estimators = est, max_depth = depth)
        rfr.fit(xt_train,y_train)
        rfr_predict = rfr.predict(xt_valid)
        result = sqrt(mse(y_valid, rfr_predict))
        if result < best_result:
            best_model = rfr
            best_result = result
            best_est = est
            best_depth = depth

# %% [markdown]
# #### **Строим модель с лучшими гиперпараметрами, предсказывая валидационную выборку:**

# %%
rfr_start = time.perf_counter()

rfr = best_model                   #Обучение
rfr.fit(xt_train,y_train)

rfr_stop = time.perf_counter()
rfr_time_fit = round((rfr_stop - rfr_start) * 1000)

rfr_start = time.perf_counter()

y_pred = rfr.predict(xt_valid) # предсказание

rfr_stop = time.perf_counter()
rfr_time_predict = round((rfr_stop - rfr_start) * 1000)

rfr_std = sqrt(mse(y_valid, y_pred))

# %% [markdown]
# ### CatBoostRegressor

# %%
cat = CatBoostRegressor(loss_function = 'RMSE')
cat_par = {'depth':[6,9], 'learning_rate':np.arange(0.03, 0.1, 0.25)}
cat_grid = cat.grid_search(cat_par, Pool(xs_train,y_train, cat_features = obj_col),
                          cv = 3, verbose = True, plot = False)
# Out:
# 0:	learn: 6411.8493769	test: 6370.5879868	best: 6370.5879868 (0)	total: 380ms	remaining: 6m 19s
# 1:	learn: 6250.7253764	test: 6209.4102799	best: 6209.4102799 (1)	total: 733ms	remaining: 6m 5s
# 2:	learn: 6095.4919875	test: 6054.7733580	best: 6054.7733580 (2)	total: 1.01s	remaining: 5m 36s
# 3:	learn: 5946.6498088	test: 5905.6283139	best: 5905.6283139 (3)	total: 1.35s	remaining: 5m 35s
# 4:	learn: 5800.7381794	test: 5759.1468831	best: 5759.1468831 (4)	total: 1.62s	remaining: 5m 22s
# 5:	learn: 5660.8616827	test: 5620.5636275	best: 5620.5636275 (5)	total: 1.87s	remaining: 5m 9s
# 6:	learn: 5525.9520945	test: 5485.4539269	best: 5485.4539269 (6)	total: 2.16s	remaining: 5m 7s
# 7:	learn: 5394.6277578	test: 5354.3339976	best: 5354.3339976 (7)	total: 2.44s	remaining: 5m 2s
# 8:	learn: 5267.7706708	test: 5227.2958588	best: 5227.2958588 (8)	total: 2.66s	remaining: 4m 53s
# 9:	learn: 5144.6511754	test: 5104.1505953	best: 5104.1505953 (9)	total: 2.96s	remaining: 4m 53s
# 10:	learn: 5025.4227401	test: 4984.4362285	best: 4984.4362285 (10)	total: 3.28s	remaining: 4m 54s
# 11:	learn: 4910.8360622	test: 4869.4943578	best: 4869.4943578 (11)	total: 3.53s	remaining: 4m 50s
# 12:	learn: 4799.3873702	test: 4759.5265095	best: 4759.5265095 (12)	total: 3.8s	remaining: 4m 48s
# 13:	learn: 4692.0316221	test: 4651.5939892	best: 4651.5939892 (13)	total: 4.09s	remaining: 4m 47s
# 14:	learn: 4590.5171588	test: 4550.2820717	best: 4550.2820717 (14)	total: 4.4s	remaining: 4m 48s
# 15:	learn: 4490.0389823	test: 4449.3343467	best: 4449.3343467 (15)	total: 4.66s	remaining: 4m 46s
# 16:	learn: 4393.1770112	test: 4352.1799411	best: 4352.1799411 (16)	total: 4.96s	remaining: 4m 46s
# 17:	learn: 4299.5223268	test: 4258.2426060	best: 4258.2426060 (17)	total: 5.23s	remaining: 4m 45s
# 18:	learn: 4208.9563262	test: 4167.4586166	best: 4167.4586166 (18)	total: 5.49s	remaining: 4m 43s
# 19:	learn: 4122.5833840	test: 4080.5506062	best: 4080.5506062 (19)	total: 5.77s	remaining: 4m 42s
# 20:	learn: 4038.9159030	test: 3996.5158105	best: 3996.5158105 (20)	total: 6.02s	remaining: 4m 40s
# 21:	learn: 3956.5835622	test: 3913.9968039	best: 3913.9968039 (21)	total: 6.33s	remaining: 4m 41s
# 22:	learn: 3878.4319960	test: 3835.3470960	best: 3835.3470960 (22)	total: 6.64s	remaining: 4m 42s
# 23:	learn: 3803.1328564	test: 3759.6124624	best: 3759.6124624 (23)	total: 6.92s	remaining: 4m 41s
# 24:	learn: 3731.4871090	test: 3687.8010502	best: 3687.8010502 (24)	total: 7.17s	remaining: 4m 39s
# 25:	learn: 3661.8419115	test: 3617.3704018	best: 3617.3704018 (25)	total: 7.45s	remaining: 4m 38s
# 26:	learn: 3594.2865072	test: 3549.3242975	best: 3549.3242975 (26)	total: 7.75s	remaining: 4m 39s
# 27:	learn: 3528.5330376	test: 3484.3565463	best: 3484.3565463 (27)	total: 8.02s	remaining: 4m 38s
# 28:	learn: 3465.0798316	test: 3420.8865615	best: 3420.8865615 (28)	total: 8.3s	remaining: 4m 38s
# 29:	learn: 3403.5331213	test: 3357.7573710	best: 3357.7573710 (29)	total: 8.63s	remaining: 4m 38s
# 30:	learn: 3345.4557278	test: 3299.9305789	best: 3299.9305789 (30)	total: 8.87s	remaining: 4m 37s
# 31:	learn: 3288.5514428	test: 3242.6751201	best: 3242.6751201 (31)	total: 9.13s	remaining: 4m 36s
# 32:	learn: 3233.6754970	test: 3187.7224159	best: 3187.7224159 (32)	total: 9.37s	remaining: 4m 34s
# 33:	learn: 3181.4160965	test: 3135.5090870	best: 3135.5090870 (33)	total: 9.65s	remaining: 4m 34s
# 34:	learn: 3131.4200611	test: 3085.5810084	best: 3085.5810084 (34)	total: 9.93s	remaining: 4m 33s
# 35:	learn: 3082.3498002	test: 3036.4207136	best: 3036.4207136 (35)	total: 10.3s	remaining: 4m 34s
# 36:	learn: 3034.4863122	test: 2988.1878002	best: 2988.1878002 (36)	total: 10.5s	remaining: 4m 34s
# 37:	learn: 2989.8552978	test: 2943.5590923	best: 2943.5590923 (37)	total: 10.8s	remaining: 4m 34s
# 38:	learn: 2947.2269107	test: 2899.9228598	best: 2899.9228598 (38)	total: 11.1s	remaining: 4m 34s
# 39:	learn: 2906.6098991	test: 2859.0007301	best: 2859.0007301 (39)	total: 11.4s	remaining: 4m 33s
# 40:	learn: 2866.7924602	test: 2818.9321172	best: 2818.9321172 (40)	total: 11.6s	remaining: 4m 31s
# 41:	learn: 2826.9959280	test: 2779.5598937	best: 2779.5598937 (41)	total: 11.9s	remaining: 4m 31s
# 42:	learn: 2789.4584226	test: 2741.6722974	best: 2741.6722974 (42)	total: 12.1s	remaining: 4m 29s
# 43:	learn: 2753.2034760	test: 2704.8283518	best: 2704.8283518 (43)	total: 12.4s	remaining: 4m 30s
# 44:	learn: 2718.8933797	test: 2670.6518303	best: 2670.6518303 (44)	total: 12.7s	remaining: 4m 30s
# 45:	learn: 2687.2768513	test: 2638.9666764	best: 2638.9666764 (45)	total: 13.1s	remaining: 4m 30s
# 46:	learn: 2655.6268212	test: 2607.2494721	best: 2607.2494721 (46)	total: 13.4s	remaining: 4m 30s
# 47:	learn: 2624.7294557	test: 2576.0566815	best: 2576.0566815 (47)	total: 13.6s	remaining: 4m 30s
# 48:	learn: 2596.0091487	test: 2547.1170221	best: 2547.1170221 (48)	total: 13.9s	remaining: 4m 29s
# 49:	learn: 2568.2602738	test: 2519.3873850	best: 2519.3873850 (49)	total: 14.2s	remaining: 4m 29s
# 50:	learn: 2540.5268145	test: 2491.6904837	best: 2491.6904837 (50)	total: 14.5s	remaining: 4m 29s
# 51:	learn: 2513.8853674	test: 2464.4589002	best: 2464.4589002 (51)	total: 14.7s	remaining: 4m 28s
# 52:	learn: 2488.3869790	test: 2438.4811068	best: 2438.4811068 (52)	total: 15.1s	remaining: 4m 29s
# 53:	learn: 2464.6420184	test: 2414.7244730	best: 2414.7244730 (53)	total: 15.3s	remaining: 4m 28s
# 54:	learn: 2441.3247338	test: 2390.7829453	best: 2390.7829453 (54)	total: 15.6s	remaining: 4m 28s
# 55:	learn: 2419.0571596	test: 2368.6005821	best: 2368.6005821 (55)	total: 15.9s	remaining: 4m 27s
# 56:	learn: 2398.4096154	test: 2348.6581323	best: 2348.6581323 (56)	total: 16.1s	remaining: 4m 26s
# 57:	learn: 2378.3005251	test: 2328.7126285	best: 2328.7126285 (57)	total: 16.4s	remaining: 4m 25s
# 58:	learn: 2358.0755440	test: 2308.1119010	best: 2308.1119010 (58)	total: 16.7s	remaining: 4m 26s
# 59:	learn: 2337.9933426	test: 2287.7696679	best: 2287.7696679 (59)	total: 17s	remaining: 4m 26s
# 60:	learn: 2319.2684955	test: 2268.7776353	best: 2268.7776353 (60)	total: 17.3s	remaining: 4m 26s
# 61:	learn: 2301.6173154	test: 2251.4524928	best: 2251.4524928 (61)	total: 17.6s	remaining: 4m 26s
# 62:	learn: 2284.9915644	test: 2234.8796445	best: 2234.8796445 (62)	total: 17.9s	remaining: 4m 25s
# 63:	learn: 2268.6092025	test: 2218.2720097	best: 2218.2720097 (63)	total: 18.2s	remaining: 4m 26s
# 64:	learn: 2252.4058543	test: 2202.3594831	best: 2202.3594831 (64)	total: 18.5s	remaining: 4m 25s
# 65:	learn: 2236.8371810	test: 2186.7722446	best: 2186.7722446 (65)	total: 18.8s	remaining: 4m 26s
# 66:	learn: 2222.5348266	test: 2172.7364597	best: 2172.7364597 (66)	total: 19.1s	remaining: 4m 26s
# 67:	learn: 2209.0652707	test: 2159.3613886	best: 2159.3613886 (67)	total: 19.4s	remaining: 4m 25s
# 68:	learn: 2195.7656157	test: 2146.3047253	best: 2146.3047253 (68)	total: 19.7s	remaining: 4m 25s
# 69:	learn: 2183.3528002	test: 2133.9399246	best: 2133.9399246 (69)	total: 20s	remaining: 4m 25s
# 70:	learn: 2171.0342149	test: 2121.5563679	best: 2121.5563679 (70)	total: 20.3s	remaining: 4m 25s
# 71:	learn: 2158.4892109	test: 2109.3704570	best: 2109.3704570 (71)	total: 20.6s	remaining: 4m 25s
# 72:	learn: 2146.6208417	test: 2097.2846519	best: 2097.2846519 (72)	total: 20.9s	remaining: 4m 25s
# 73:	learn: 2134.9539170	test: 2084.8449466	best: 2084.8449466 (73)	total: 21.2s	remaining: 4m 25s
# 74:	learn: 2124.0099571	test: 2073.7242081	best: 2073.7242081 (74)	total: 21.5s	remaining: 4m 25s
# 75:	learn: 2114.1455952	test: 2064.2570638	best: 2064.2570638 (75)	total: 21.7s	remaining: 4m 24s
# 76:	learn: 2103.8935976	test: 2053.9081957	best: 2053.9081957 (76)	total: 22s	remaining: 4m 24s
# 77:	learn: 2093.4350180	test: 2043.6330528	best: 2043.6330528 (77)	total: 22.4s	remaining: 4m 24s
# 78:	learn: 2084.3253998	test: 2034.7052627	best: 2034.7052627 (78)	total: 22.7s	remaining: 4m 24s
# 79:	learn: 2075.4085093	test: 2025.8323224	best: 2025.8323224 (79)	total: 23s	remaining: 4m 24s
# 80:	learn: 2067.0785648	test: 2017.6993702	best: 2017.6993702 (80)	total: 23.3s	remaining: 4m 23s
# 81:	learn: 2058.6629406	test: 2009.6159545	best: 2009.6159545 (81)	total: 23.5s	remaining: 4m 23s
# 82:	learn: 2050.9636980	test: 2002.0187993	best: 2002.0187993 (82)	total: 23.8s	remaining: 4m 23s
# 83:	learn: 2043.2419912	test: 1994.1582073	best: 1994.1582073 (83)	total: 24.2s	remaining: 4m 23s
# 84:	learn: 2036.1744929	test: 1987.2691656	best: 1987.2691656 (84)	total: 24.4s	remaining: 4m 23s
# 85:	learn: 2028.7037266	test: 1979.8010950	best: 1979.8010950 (85)	total: 24.7s	remaining: 4m 22s
# 86:	learn: 2022.1288295	test: 1973.2927924	best: 1973.2927924 (86)	total: 25s	remaining: 4m 22s
# 87:	learn: 2014.9639274	test: 1966.3335016	best: 1966.3335016 (87)	total: 25.4s	remaining: 4m 22s
# 88:	learn: 2007.8412021	test: 1959.4507905	best: 1959.4507905 (88)	total: 25.7s	remaining: 4m 22s
# 89:	learn: 2001.7835732	test: 1953.5622189	best: 1953.5622189 (89)	total: 25.9s	remaining: 4m 22s
# 90:	learn: 1996.0909218	test: 1947.9663895	best: 1947.9663895 (90)	total: 26.2s	remaining: 4m 21s
# 91:	learn: 1990.5223236	test: 1942.6231222	best: 1942.6231222 (91)	total: 26.4s	remaining: 4m 20s
# 92:	learn: 1984.9609760	test: 1937.1658674	best: 1937.1658674 (92)	total: 26.7s	remaining: 4m 20s
# 93:	learn: 1979.6395507	test: 1931.8016101	best: 1931.8016101 (93)	total: 27s	remaining: 4m 20s
# 94:	learn: 1974.6742466	test: 1927.0785879	best: 1927.0785879 (94)	total: 27.4s	remaining: 4m 21s
# 95:	learn: 1969.3144524	test: 1921.6906292	best: 1921.6906292 (95)	total: 27.9s	remaining: 4m 22s
# 96:	learn: 1965.1296534	test: 1916.9654950	best: 1916.9654950 (96)	total: 28.3s	remaining: 4m 23s
# 97:	learn: 1960.5103899	test: 1912.4289701	best: 1912.4289701 (97)	total: 28.6s	remaining: 4m 23s
# 98:	learn: 1955.7053231	test: 1907.6981551	best: 1907.6981551 (98)	total: 28.9s	remaining: 4m 22s
# 99:	learn: 1951.1951976	test: 1902.8953897	best: 1902.8953897 (99)	total: 29.2s	remaining: 4m 22s
# 100:	learn: 1947.2961180	test: 1899.0304724	best: 1899.0304724 (100)	total: 29.4s	remaining: 4m 21s
# 101:	learn: 1942.6670175	test: 1894.5937012	best: 1894.5937012 (101)	total: 29.7s	remaining: 4m 21s
# 102:	learn: 1938.2639021	test: 1890.3740102	best: 1890.3740102 (102)	total: 30s	remaining: 4m 21s
# 103:	learn: 1934.1663873	test: 1886.3429180	best: 1886.3429180 (103)	total: 30.3s	remaining: 4m 20s
# 104:	learn: 1930.4304944	test: 1882.6934746	best: 1882.6934746 (104)	total: 30.5s	remaining: 4m 20s
# 105:	learn: 1926.9084480	test: 1879.2393489	best: 1879.2393489 (105)	total: 30.8s	remaining: 4m 19s
# 106:	learn: 1923.4750413	test: 1876.0466803	best: 1876.0466803 (106)	total: 31.1s	remaining: 4m 19s
# 107:	learn: 1919.5997286	test: 1872.3550137	best: 1872.3550137 (107)	total: 31.4s	remaining: 4m 19s
# 108:	learn: 1915.9377935	test: 1868.6529575	best: 1868.6529575 (108)	total: 31.8s	remaining: 4m 19s
# 109:	learn: 1913.0401770	test: 1865.8844276	best: 1865.8844276 (109)	total: 32s	remaining: 4m 19s
# 110:	learn: 1910.0287796	test: 1863.0017363	best: 1863.0017363 (110)	total: 32.3s	remaining: 4m 18s
# 111:	learn: 1907.0739930	test: 1860.0995948	best: 1860.0995948 (111)	total: 32.6s	remaining: 4m 18s
# 112:	learn: 1904.0401335	test: 1857.1382019	best: 1857.1382019 (112)	total: 32.9s	remaining: 4m 18s
# 113:	learn: 1900.7623563	test: 1854.0388534	best: 1854.0388534 (113)	total: 33.2s	remaining: 4m 18s
# 114:	learn: 1897.8800009	test: 1851.1631001	best: 1851.1631001 (114)	total: 33.5s	remaining: 4m 17s
# 115:	learn: 1894.9352898	test: 1848.2506417	best: 1848.2506417 (115)	total: 33.8s	remaining: 4m 17s
# 116:	learn: 1892.5451909	test: 1845.9355857	best: 1845.9355857 (116)	total: 34s	remaining: 4m 16s
# 117:	learn: 1890.0657726	test: 1843.5288550	best: 1843.5288550 (117)	total: 34.3s	remaining: 4m 16s
# 118:	learn: 1887.3959985	test: 1840.9773527	best: 1840.9773527 (118)	total: 34.6s	remaining: 4m 16s
# 119:	learn: 1884.8046633	test: 1838.4753401	best: 1838.4753401 (119)	total: 34.9s	remaining: 4m 15s
# 120:	learn: 1882.3647364	test: 1836.0763849	best: 1836.0763849 (120)	total: 35.2s	remaining: 4m 15s
# 121:	learn: 1879.8385055	test: 1833.5786823	best: 1833.5786823 (121)	total: 35.5s	remaining: 4m 15s
# 122:	learn: 1877.4493241	test: 1831.2828999	best: 1831.2828999 (122)	total: 35.8s	remaining: 4m 14s
# 123:	learn: 1875.1438225	test: 1828.9086275	best: 1828.9086275 (123)	total: 36.1s	remaining: 4m 14s
# 124:	learn: 1872.6516828	test: 1826.7056370	best: 1826.7056370 (124)	total: 36.3s	remaining: 4m 14s
# 125:	learn: 1870.3932768	test: 1824.4963656	best: 1824.4963656 (125)	total: 36.6s	remaining: 4m 13s
# 126:	learn: 1868.4453768	test: 1822.6313967	best: 1822.6313967 (126)	total: 36.8s	remaining: 4m 13s
# 127:	learn: 1866.4311254	test: 1820.6307786	best: 1820.6307786 (127)	total: 37s	remaining: 4m 12s
# 128:	learn: 1863.9617542	test: 1818.2974773	best: 1818.2974773 (128)	total: 37.3s	remaining: 4m 11s
# 129:	learn: 1861.7896111	test: 1816.1079771	best: 1816.1079771 (129)	total: 37.6s	remaining: 4m 11s
# 130:	learn: 1859.5316220	test: 1813.8647876	best: 1813.8647876 (130)	total: 37.9s	remaining: 4m 11s
# 131:	learn: 1857.3586749	test: 1811.8922722	best: 1811.8922722 (131)	total: 38.2s	remaining: 4m 11s
# 132:	learn: 1855.3845204	test: 1809.8151223	best: 1809.8151223 (132)	total: 38.5s	remaining: 4m 10s
# 133:	learn: 1853.5394016	test: 1808.2676501	best: 1808.2676501 (133)	total: 38.8s	remaining: 4m 10s
# 134:	learn: 1851.4358952	test: 1806.3097786	best: 1806.3097786 (134)	total: 39.1s	remaining: 4m 10s
# 135:	learn: 1849.4959287	test: 1804.4043946	best: 1804.4043946 (135)	total: 39.3s	remaining: 4m 9s
# 136:	learn: 1847.5071535	test: 1802.6880238	best: 1802.6880238 (136)	total: 39.5s	remaining: 4m 8s
# 137:	learn: 1845.6427345	test: 1800.8506301	best: 1800.8506301 (137)	total: 39.8s	remaining: 4m 8s
# 138:	learn: 1844.0273470	test: 1799.3638480	best: 1799.3638480 (138)	total: 40s	remaining: 4m 7s
# 139:	learn: 1842.2765205	test: 1797.6680344	best: 1797.6680344 (139)	total: 40.3s	remaining: 4m 7s
# 140:	learn: 1840.3166695	test: 1795.8137647	best: 1795.8137647 (140)	total: 40.5s	remaining: 4m 6s
# 141:	learn: 1838.7261157	test: 1794.2865742	best: 1794.2865742 (141)	total: 40.8s	remaining: 4m 6s
# 142:	learn: 1837.1447692	test: 1792.8201671	best: 1792.8201671 (142)	total: 41.2s	remaining: 4m 6s
# 143:	learn: 1835.5919499	test: 1791.3038862	best: 1791.3038862 (143)	total: 41.5s	remaining: 4m 6s
# 144:	learn: 1834.1101430	test: 1789.9393705	best: 1789.9393705 (144)	total: 41.7s	remaining: 4m 6s
# 145:	learn: 1832.6595291	test: 1788.4908251	best: 1788.4908251 (145)	total: 42s	remaining: 4m 5s
# 146:	learn: 1831.3858809	test: 1787.2678849	best: 1787.2678849 (146)	total: 42.2s	remaining: 4m 5s
# 147:	learn: 1829.9182843	test: 1785.7898473	best: 1785.7898473 (147)	total: 42.5s	remaining: 4m 4s
# 148:	learn: 1828.6928674	test: 1784.5337139	best: 1784.5337139 (148)	total: 42.8s	remaining: 4m 4s
# 149:	learn: 1827.5220821	test: 1783.4181442	best: 1783.4181442 (149)	total: 43s	remaining: 4m 3s
# 150:	learn: 1826.0415362	test: 1782.0577343	best: 1782.0577343 (150)	total: 43.3s	remaining: 4m 3s
# 151:	learn: 1824.4949881	test: 1780.5604261	best: 1780.5604261 (151)	total: 43.5s	remaining: 4m 2s
# 152:	learn: 1823.0055673	test: 1779.1375003	best: 1779.1375003 (152)	total: 43.8s	remaining: 4m 2s
# 153:	learn: 1821.2191478	test: 1777.3539322	best: 1777.3539322 (153)	total: 44.1s	remaining: 4m 2s
# 154:	learn: 1820.1433951	test: 1776.3789705	best: 1776.3789705 (154)	total: 44.3s	remaining: 4m 1s
# 155:	learn: 1818.8592752	test: 1775.1774636	best: 1775.1774636 (155)	total: 44.7s	remaining: 4m 1s
# 156:	learn: 1817.9451228	test: 1774.4015310	best: 1774.4015310 (156)	total: 44.9s	remaining: 4m 1s
# 157:	learn: 1816.3275499	test: 1772.9616020	best: 1772.9616020 (157)	total: 45.2s	remaining: 4m 1s
# 158:	learn: 1814.9436129	test: 1771.5353083	best: 1771.5353083 (158)	total: 45.5s	remaining: 4m
# 159:	learn: 1813.8638191	test: 1770.2868062	best: 1770.2868062 (159)	total: 45.8s	remaining: 4m
# 160:	learn: 1812.7812302	test: 1769.3515778	best: 1769.3515778 (160)	total: 46s	remaining: 3m 59s
# 161:	learn: 1811.2384063	test: 1767.9611290	best: 1767.9611290 (161)	total: 46.3s	remaining: 3m 59s
# 162:	learn: 1810.3076284	test: 1767.1361035	best: 1767.1361035 (162)	total: 46.6s	remaining: 3m 59s
# 163:	learn: 1809.2757246	test: 1766.2915802	best: 1766.2915802 (163)	total: 46.8s	remaining: 3m 58s
# 164:	learn: 1807.8374620	test: 1764.8746742	best: 1764.8746742 (164)	total: 47s	remaining: 3m 58s
# 165:	learn: 1806.6389053	test: 1763.7157894	best: 1763.7157894 (165)	total: 47.3s	remaining: 3m 57s
# 166:	learn: 1805.6251321	test: 1762.6701925	best: 1762.6701925 (166)	total: 47.6s	remaining: 3m 57s
# 167:	learn: 1804.1076999	test: 1761.1607206	best: 1761.1607206 (167)	total: 47.8s	remaining: 3m 56s
# 168:	learn: 1803.2786550	test: 1760.3606930	best: 1760.3606930 (168)	total: 48.1s	remaining: 3m 56s
# 169:	learn: 1802.4062926	test: 1759.6000563	best: 1759.6000563 (169)	total: 48.5s	remaining: 3m 56s
# 170:	learn: 1800.9689371	test: 1758.2128445	best: 1758.2128445 (170)	total: 48.7s	remaining: 3m 56s
# 171:	learn: 1799.6298450	test: 1757.1291636	best: 1757.1291636 (171)	total: 49s	remaining: 3m 55s
# 172:	learn: 1798.7195442	test: 1756.2005543	best: 1756.2005543 (172)	total: 49.3s	remaining: 3m 55s
# 173:	learn: 1797.4498867	test: 1754.8188815	best: 1754.8188815 (173)	total: 49.6s	remaining: 3m 55s
# 174:	learn: 1796.0104379	test: 1753.5377734	best: 1753.5377734 (174)	total: 49.8s	remaining: 3m 54s
# 175:	learn: 1795.1325243	test: 1752.6813100	best: 1752.6813100 (175)	total: 50.1s	remaining: 3m 54s
# 176:	learn: 1794.1469387	test: 1751.6642706	best: 1751.6642706 (176)	total: 50.4s	remaining: 3m 54s
# 177:	learn: 1793.3972761	test: 1751.0358449	best: 1751.0358449 (177)	total: 50.6s	remaining: 3m 53s
# 178:	learn: 1792.4911178	test: 1750.4026541	best: 1750.4026541 (178)	total: 50.9s	remaining: 3m 53s
# 179:	learn: 1791.6821207	test: 1749.6514211	best: 1749.6514211 (179)	total: 51.1s	remaining: 3m 53s
# 180:	learn: 1790.9002034	test: 1748.9006847	best: 1748.9006847 (180)	total: 51.5s	remaining: 3m 52s
# 181:	learn: 1789.6212037	test: 1747.7308668	best: 1747.7308668 (181)	total: 51.7s	remaining: 3m 52s
# 182:	learn: 1788.6895670	test: 1746.8735181	best: 1746.8735181 (182)	total: 52s	remaining: 3m 52s
# 183:	learn: 1787.9379367	test: 1746.1499443	best: 1746.1499443 (183)	total: 52.3s	remaining: 3m 51s
# 184:	learn: 1787.0369767	test: 1745.2669431	best: 1745.2669431 (184)	total: 52.6s	remaining: 3m 51s
# 185:	learn: 1786.3210124	test: 1744.6214506	best: 1744.6214506 (185)	total: 52.9s	remaining: 3m 51s
# 186:	learn: 1785.6850407	test: 1744.0599360	best: 1744.0599360 (186)	total: 53.2s	remaining: 3m 51s
# 187:	learn: 1784.9875423	test: 1743.5310348	best: 1743.5310348 (187)	total: 53.4s	remaining: 3m 50s
# 188:	learn: 1784.3146806	test: 1742.8578119	best: 1742.8578119 (188)	total: 53.7s	remaining: 3m 50s
# 189:	learn: 1783.0586864	test: 1741.9213836	best: 1741.9213836 (189)	total: 54s	remaining: 3m 50s
# 190:	learn: 1782.0460281	test: 1740.9536716	best: 1740.9536716 (190)	total: 54.3s	remaining: 3m 49s
# 191:	learn: 1781.0349726	test: 1739.9355995	best: 1739.9355995 (191)	total: 54.5s	remaining: 3m 49s
# 192:	learn: 1780.1798570	test: 1739.1379058	best: 1739.1379058 (192)	total: 54.8s	remaining: 3m 48s
# 193:	learn: 1779.6186217	test: 1738.6090824	best: 1738.6090824 (193)	total: 55.1s	remaining: 3m 48s
# 194:	learn: 1778.9243108	test: 1737.9445437	best: 1737.9445437 (194)	total: 55.4s	remaining: 3m 48s
# 195:	learn: 1777.9062463	test: 1737.1250537	best: 1737.1250537 (195)	total: 55.7s	remaining: 3m 48s
# 196:	learn: 1777.2586398	test: 1736.5621404	best: 1736.5621404 (196)	total: 55.9s	remaining: 3m 47s
# 197:	learn: 1776.2148325	test: 1735.6998221	best: 1735.6998221 (197)	total: 56.2s	remaining: 3m 47s
# 198:	learn: 1775.6053820	test: 1735.0112713	best: 1735.0112713 (198)	total: 56.4s	remaining: 3m 47s
# 199:	learn: 1775.0209334	test: 1734.4781260	best: 1734.4781260 (199)	total: 56.7s	remaining: 3m 46s
# 200:	learn: 1774.4507786	test: 1733.9527018	best: 1733.9527018 (200)	total: 57s	remaining: 3m 46s
# 201:	learn: 1773.4924786	test: 1733.0027078	best: 1733.0027078 (201)	total: 57.2s	remaining: 3m 46s
# 202:	learn: 1772.8600369	test: 1732.4350533	best: 1732.4350533 (202)	total: 57.5s	remaining: 3m 45s
# 203:	learn: 1772.2816153	test: 1732.0020050	best: 1732.0020050 (203)	total: 57.8s	remaining: 3m 45s
# 204:	learn: 1771.5214669	test: 1731.1702614	best: 1731.1702614 (204)	total: 58.1s	remaining: 3m 45s
# 205:	learn: 1770.5421039	test: 1730.3858720	best: 1730.3858720 (205)	total: 58.3s	remaining: 3m 44s
# 206:	learn: 1769.9921985	test: 1729.8662692	best: 1729.8662692 (206)	total: 58.6s	remaining: 3m 44s
# 207:	learn: 1769.3441407	test: 1729.0674752	best: 1729.0674752 (207)	total: 58.8s	remaining: 3m 43s
# 208:	learn: 1768.5780786	test: 1728.3992761	best: 1728.3992761 (208)	total: 59s	remaining: 3m 43s
# 209:	learn: 1767.7023818	test: 1727.6218632	best: 1727.6218632 (209)	total: 59.3s	remaining: 3m 42s
# 210:	learn: 1767.1806581	test: 1727.1758864	best: 1727.1758864 (210)	total: 59.5s	remaining: 3m 42s
# 211:	learn: 1766.4695609	test: 1726.7093266	best: 1726.7093266 (211)	total: 59.8s	remaining: 3m 42s
# 212:	learn: 1765.8607312	test: 1726.1003225	best: 1726.1003225 (212)	total: 1m	remaining: 3m 42s
# 213:	learn: 1764.9293051	test: 1725.4028065	best: 1725.4028065 (213)	total: 1m	remaining: 3m 41s
# 214:	learn: 1764.0296024	test: 1724.5965183	best: 1724.5965183 (214)	total: 1m	remaining: 3m 41s
# 215:	learn: 1763.1029638	test: 1723.6721751	best: 1723.6721751 (215)	total: 1m	remaining: 3m 41s
# 216:	learn: 1762.4948920	test: 1723.1196012	best: 1723.1196012 (216)	total: 1m 1s	remaining: 3m 40s
# 217:	learn: 1761.7014292	test: 1722.4248344	best: 1722.4248344 (217)	total: 1m 1s	remaining: 3m 40s
# 218:	learn: 1760.9032918	test: 1721.7431690	best: 1721.7431690 (218)	total: 1m 1s	remaining: 3m 40s
# 219:	learn: 1760.4169362	test: 1721.3592207	best: 1721.3592207 (219)	total: 1m 2s	remaining: 3m 39s
# 220:	learn: 1760.0064375	test: 1720.9999793	best: 1720.9999793 (220)	total: 1m 2s	remaining: 3m 39s
# 221:	learn: 1759.1968176	test: 1720.2010835	best: 1720.2010835 (221)	total: 1m 2s	remaining: 3m 39s
# 222:	learn: 1758.6066689	test: 1719.5973118	best: 1719.5973118 (222)	total: 1m 2s	remaining: 3m 38s
# 223:	learn: 1758.1887061	test: 1719.1089536	best: 1719.1089536 (223)	total: 1m 3s	remaining: 3m 38s
# 224:	learn: 1757.8265153	test: 1718.6784721	best: 1718.6784721 (224)	total: 1m 3s	remaining: 3m 37s
# 225:	learn: 1757.3510756	test: 1718.2948256	best: 1718.2948256 (225)	total: 1m 3s	remaining: 3m 37s
# 226:	learn: 1756.5183905	test: 1717.5518467	best: 1717.5518467 (226)	total: 1m 3s	remaining: 3m 37s
# 227:	learn: 1756.0413154	test: 1717.0662848	best: 1717.0662848 (227)	total: 1m 4s	remaining: 3m 36s
# 228:	learn: 1755.6525306	test: 1716.6683784	best: 1716.6683784 (228)	total: 1m 4s	remaining: 3m 36s
# 229:	learn: 1754.8450179	test: 1716.0362530	best: 1716.0362530 (229)	total: 1m 4s	remaining: 3m 36s
# 230:	learn: 1753.9945456	test: 1715.2815056	best: 1715.2815056 (230)	total: 1m 4s	remaining: 3m 35s
# 231:	learn: 1753.4708312	test: 1714.7919441	best: 1714.7919441 (231)	total: 1m 5s	remaining: 3m 35s
# 232:	learn: 1753.1918472	test: 1714.4859764	best: 1714.4859764 (232)	total: 1m 5s	remaining: 3m 35s
# 233:	learn: 1752.6688101	test: 1714.0398467	best: 1714.0398467 (233)	total: 1m 5s	remaining: 3m 34s
# 234:	learn: 1752.3019009	test: 1713.6325057	best: 1713.6325057 (234)	total: 1m 5s	remaining: 3m 34s
# 235:	learn: 1751.7750992	test: 1713.2076263	best: 1713.2076263 (235)	total: 1m 6s	remaining: 3m 34s
# 236:	learn: 1751.1387077	test: 1712.5604183	best: 1712.5604183 (236)	total: 1m 6s	remaining: 3m 33s
# 237:	learn: 1750.6616971	test: 1712.0945031	best: 1712.0945031 (237)	total: 1m 6s	remaining: 3m 33s
# 238:	learn: 1750.0017777	test: 1711.4541065	best: 1711.4541065 (238)	total: 1m 6s	remaining: 3m 32s
# 239:	learn: 1749.5905017	test: 1711.1080718	best: 1711.1080718 (239)	total: 1m 7s	remaining: 3m 32s
# 240:	learn: 1749.1355503	test: 1710.7125214	best: 1710.7125214 (240)	total: 1m 7s	remaining: 3m 32s
# 241:	learn: 1748.7553289	test: 1710.3704802	best: 1710.3704802 (241)	total: 1m 7s	remaining: 3m 32s
# 242:	learn: 1748.1151949	test: 1709.7478133	best: 1709.7478133 (242)	total: 1m 7s	remaining: 3m 31s
# 243:	learn: 1747.5626768	test: 1709.3038276	best: 1709.3038276 (243)	total: 1m 8s	remaining: 3m 31s
# 244:	learn: 1747.0851101	test: 1708.8585607	best: 1708.8585607 (244)	total: 1m 8s	remaining: 3m 31s
# 245:	learn: 1746.7268704	test: 1708.4466628	best: 1708.4466628 (245)	total: 1m 8s	remaining: 3m 31s
# 246:	learn: 1746.0446889	test: 1707.7103317	best: 1707.7103317 (246)	total: 1m 9s	remaining: 3m 30s
# 247:	learn: 1745.6928930	test: 1707.3798065	best: 1707.3798065 (247)	total: 1m 9s	remaining: 3m 30s
# 248:	learn: 1745.0296037	test: 1706.9096474	best: 1706.9096474 (248)	total: 1m 9s	remaining: 3m 30s
# 249:	learn: 1744.5036321	test: 1706.3385829	best: 1706.3385829 (249)	total: 1m 9s	remaining: 3m 29s
# 250:	learn: 1743.9801760	test: 1705.8948439	best: 1705.8948439 (250)	total: 1m 10s	remaining: 3m 29s
# 251:	learn: 1743.6537081	test: 1705.5789836	best: 1705.5789836 (251)	total: 1m 10s	remaining: 3m 28s
# 252:	learn: 1743.1778432	test: 1705.2598252	best: 1705.2598252 (252)	total: 1m 10s	remaining: 3m 28s
# 253:	learn: 1742.7768123	test: 1704.8311824	best: 1704.8311824 (253)	total: 1m 10s	remaining: 3m 27s
# 254:	learn: 1742.2992718	test: 1704.3515039	best: 1704.3515039 (254)	total: 1m 11s	remaining: 3m 27s
# 255:	learn: 1741.7779436	test: 1703.9027175	best: 1703.9027175 (255)	total: 1m 11s	remaining: 3m 27s
# 256:	learn: 1741.3267904	test: 1703.4366658	best: 1703.4366658 (256)	total: 1m 11s	remaining: 3m 26s
# 257:	learn: 1740.9622822	test: 1703.1170066	best: 1703.1170066 (257)	total: 1m 11s	remaining: 3m 26s
# 258:	learn: 1740.4636994	test: 1702.6432813	best: 1702.6432813 (258)	total: 1m 11s	remaining: 3m 25s
# 259:	learn: 1739.5479813	test: 1701.7150964	best: 1701.7150964 (259)	total: 1m 12s	remaining: 3m 25s
# 260:	learn: 1739.0214663	test: 1701.0751724	best: 1701.0751724 (260)	total: 1m 12s	remaining: 3m 25s
# 261:	learn: 1738.3729577	test: 1700.5239259	best: 1700.5239259 (261)	total: 1m 12s	remaining: 3m 24s
# 262:	learn: 1737.8188054	test: 1699.9190525	best: 1699.9190525 (262)	total: 1m 13s	remaining: 3m 24s
# 263:	learn: 1737.1855674	test: 1699.4219267	best: 1699.4219267 (263)	total: 1m 13s	remaining: 3m 24s
# 264:	learn: 1736.8476769	test: 1699.1114676	best: 1699.1114676 (264)	total: 1m 13s	remaining: 3m 24s
# 265:	learn: 1736.3281601	test: 1698.6071213	best: 1698.6071213 (265)	total: 1m 13s	remaining: 3m 23s
# 266:	learn: 1736.0301487	test: 1698.3908157	best: 1698.3908157 (266)	total: 1m 14s	remaining: 3m 23s
# 267:	learn: 1735.1727268	test: 1697.7296365	best: 1697.7296365 (267)	total: 1m 14s	remaining: 3m 23s
# 268:	learn: 1734.8671077	test: 1697.3795112	best: 1697.3795112 (268)	total: 1m 14s	remaining: 3m 22s
# 269:	learn: 1734.1619541	test: 1696.7029397	best: 1696.7029397 (269)	total: 1m 14s	remaining: 3m 22s
# 270:	learn: 1733.5090944	test: 1696.1623748	best: 1696.1623748 (270)	total: 1m 15s	remaining: 3m 22s
# 271:	learn: 1732.9971892	test: 1695.7479362	best: 1695.7479362 (271)	total: 1m 15s	remaining: 3m 21s
# 272:	learn: 1732.4728921	test: 1695.2692836	best: 1695.2692836 (272)	total: 1m 15s	remaining: 3m 21s
# 273:	learn: 1731.9747560	test: 1694.7413409	best: 1694.7413409 (273)	total: 1m 15s	remaining: 3m 21s
# 274:	learn: 1731.3729009	test: 1694.2689431	best: 1694.2689431 (274)	total: 1m 16s	remaining: 3m 20s
# 275:	learn: 1731.0710194	test: 1693.9795368	best: 1693.9795368 (275)	total: 1m 16s	remaining: 3m 20s
# 276:	learn: 1730.6654262	test: 1693.7060517	best: 1693.7060517 (276)	total: 1m 16s	remaining: 3m 20s
# 277:	learn: 1730.3679787	test: 1693.3946493	best: 1693.3946493 (277)	total: 1m 16s	remaining: 3m 19s
# 278:	learn: 1730.0327835	test: 1693.0863701	best: 1693.0863701 (278)	total: 1m 17s	remaining: 3m 19s
# 279:	learn: 1729.6577619	test: 1692.7132037	best: 1692.7132037 (279)	total: 1m 17s	remaining: 3m 18s
# 280:	learn: 1729.3557249	test: 1692.4168983	best: 1692.4168983 (280)	total: 1m 17s	remaining: 3m 18s
# 281:	learn: 1728.8052739	test: 1691.7957652	best: 1691.7957652 (281)	total: 1m 17s	remaining: 3m 18s
# 282:	learn: 1728.4917732	test: 1691.4780040	best: 1691.4780040 (282)	total: 1m 18s	remaining: 3m 17s
# 283:	learn: 1728.0729837	test: 1691.1935835	best: 1691.1935835 (283)	total: 1m 18s	remaining: 3m 17s
# 284:	learn: 1727.6095827	test: 1690.7441220	best: 1690.7441220 (284)	total: 1m 18s	remaining: 3m 17s
# 285:	learn: 1727.1707804	test: 1690.3426582	best: 1690.3426582 (285)	total: 1m 18s	remaining: 3m 16s
# 286:	learn: 1726.8344894	test: 1690.0051027	best: 1690.0051027 (286)	total: 1m 18s	remaining: 3m 16s
# 287:	learn: 1726.3640496	test: 1689.5425020	best: 1689.5425020 (287)	total: 1m 19s	remaining: 3m 15s
# 288:	learn: 1725.4951784	test: 1688.7935244	best: 1688.7935244 (288)	total: 1m 19s	remaining: 3m 15s
# 289:	learn: 1725.2894207	test: 1688.5997230	best: 1688.5997230 (289)	total: 1m 19s	remaining: 3m 15s
# 290:	learn: 1724.6383502	test: 1688.0556368	best: 1688.0556368 (290)	total: 1m 19s	remaining: 3m 14s
# 291:	learn: 1724.0793131	test: 1687.5907911	best: 1687.5907911 (291)	total: 1m 20s	remaining: 3m 14s
# 292:	learn: 1723.5549860	test: 1687.0640652	best: 1687.0640652 (292)	total: 1m 20s	remaining: 3m 14s
# 293:	learn: 1723.3293155	test: 1686.8437054	best: 1686.8437054 (293)	total: 1m 20s	remaining: 3m 13s
# 294:	learn: 1722.8908182	test: 1686.4808495	best: 1686.4808495 (294)	total: 1m 20s	remaining: 3m 13s
# 295:	learn: 1722.4083680	test: 1686.0423367	best: 1686.0423367 (295)	total: 1m 21s	remaining: 3m 13s
# 296:	learn: 1722.1164418	test: 1685.8572485	best: 1685.8572485 (296)	total: 1m 21s	remaining: 3m 12s
# 297:	learn: 1721.6178690	test: 1685.4048991	best: 1685.4048991 (297)	total: 1m 21s	remaining: 3m 12s
# 298:	learn: 1721.2092746	test: 1685.0186396	best: 1685.0186396 (298)	total: 1m 21s	remaining: 3m 12s
# 299:	learn: 1720.8442216	test: 1684.7221733	best: 1684.7221733 (299)	total: 1m 22s	remaining: 3m 11s
# 300:	learn: 1720.3806495	test: 1684.3949757	best: 1684.3949757 (300)	total: 1m 22s	remaining: 3m 11s
# 301:	learn: 1719.8944396	test: 1683.9952750	best: 1683.9952750 (301)	total: 1m 22s	remaining: 3m 11s
# 302:	learn: 1719.4230083	test: 1683.5594120	best: 1683.5594120 (302)	total: 1m 23s	remaining: 3m 11s
# 303:	learn: 1719.0255548	test: 1683.2927401	best: 1683.2927401 (303)	total: 1m 23s	remaining: 3m 10s
# 304:	learn: 1718.6425043	test: 1683.0008067	best: 1683.0008067 (304)	total: 1m 23s	remaining: 3m 10s
# 305:	learn: 1718.1960175	test: 1682.5451070	best: 1682.5451070 (305)	total: 1m 23s	remaining: 3m 10s
# 306:	learn: 1717.7200693	test: 1682.1608323	best: 1682.1608323 (306)	total: 1m 24s	remaining: 3m 9s
# 307:	learn: 1717.2528435	test: 1681.7586368	best: 1681.7586368 (307)	total: 1m 24s	remaining: 3m 9s
# 308:	learn: 1717.0054544	test: 1681.4849856	best: 1681.4849856 (308)	total: 1m 24s	remaining: 3m 9s
# 309:	learn: 1716.6385451	test: 1681.1175665	best: 1681.1175665 (309)	total: 1m 24s	remaining: 3m 8s
# 310:	learn: 1716.4307659	test: 1680.8696752	best: 1680.8696752 (310)	total: 1m 25s	remaining: 3m 8s
# 311:	learn: 1716.1464669	test: 1680.5945124	best: 1680.5945124 (311)	total: 1m 25s	remaining: 3m 8s
# 312:	learn: 1715.9021742	test: 1680.3522814	best: 1680.3522814 (312)	total: 1m 25s	remaining: 3m 8s
# 313:	learn: 1715.6076350	test: 1680.0919292	best: 1680.0919292 (313)	total: 1m 25s	remaining: 3m 7s
# 314:	learn: 1715.3569044	test: 1679.8228391	best: 1679.8228391 (314)	total: 1m 26s	remaining: 3m 7s
# 315:	learn: 1714.9089106	test: 1679.3941154	best: 1679.3941154 (315)	total: 1m 26s	remaining: 3m 7s
# 316:	learn: 1714.4189471	test: 1678.9686122	best: 1678.9686122 (316)	total: 1m 26s	remaining: 3m 6s
# 317:	learn: 1714.1238755	test: 1678.6401318	best: 1678.6401318 (317)	total: 1m 26s	remaining: 3m 6s
# 318:	learn: 1713.9607780	test: 1678.4615950	best: 1678.4615950 (318)	total: 1m 27s	remaining: 3m 5s
# 319:	learn: 1713.2594722	test: 1677.7887732	best: 1677.7887732 (319)	total: 1m 27s	remaining: 3m 5s
# 320:	learn: 1712.9536650	test: 1677.5212778	best: 1677.5212778 (320)	total: 1m 27s	remaining: 3m 5s
# 321:	learn: 1712.7862719	test: 1677.3775195	best: 1677.3775195 (321)	total: 1m 27s	remaining: 3m 4s
# 322:	learn: 1712.5434984	test: 1677.1962107	best: 1677.1962107 (322)	total: 1m 28s	remaining: 3m 4s
# 323:	learn: 1712.1006028	test: 1676.7848692	best: 1676.7848692 (323)	total: 1m 28s	remaining: 3m 4s
# 324:	learn: 1711.7026688	test: 1676.3835878	best: 1676.3835878 (324)	total: 1m 28s	remaining: 3m 4s
# 325:	learn: 1711.3904689	test: 1676.0941809	best: 1676.0941809 (325)	total: 1m 28s	remaining: 3m 3s
# 326:	learn: 1710.9910034	test: 1675.7729186	best: 1675.7729186 (326)	total: 1m 29s	remaining: 3m 3s
# 327:	learn: 1710.4947142	test: 1675.3098736	best: 1675.3098736 (327)	total: 1m 29s	remaining: 3m 2s
# 328:	learn: 1710.0619001	test: 1674.9029153	best: 1674.9029153 (328)	total: 1m 29s	remaining: 3m 2s
# 329:	learn: 1709.8985255	test: 1674.7583140	best: 1674.7583140 (329)	total: 1m 29s	remaining: 3m 2s
# 330:	learn: 1709.4501940	test: 1674.3840683	best: 1674.3840683 (330)	total: 1m 30s	remaining: 3m 2s
# 331:	learn: 1709.1410416	test: 1674.0794299	best: 1674.0794299 (331)	total: 1m 30s	remaining: 3m 1s
# 332:	learn: 1708.6955352	test: 1673.6681675	best: 1673.6681675 (332)	total: 1m 30s	remaining: 3m 1s
# 333:	learn: 1708.2081337	test: 1673.2595439	best: 1673.2595439 (333)	total: 1m 30s	remaining: 3m 1s
# 334:	learn: 1707.7669399	test: 1672.8836644	best: 1672.8836644 (334)	total: 1m 31s	remaining: 3m
# 335:	learn: 1707.4057643	test: 1672.5105833	best: 1672.5105833 (335)	total: 1m 31s	remaining: 3m
# 336:	learn: 1707.0168085	test: 1672.1301926	best: 1672.1301926 (336)	total: 1m 31s	remaining: 3m
# 337:	learn: 1706.6641592	test: 1671.8576063	best: 1671.8576063 (337)	total: 1m 32s	remaining: 3m
# 338:	learn: 1705.9941352	test: 1671.2777160	best: 1671.2777160 (338)	total: 1m 32s	remaining: 2m 59s
# 339:	learn: 1705.6226385	test: 1671.0067893	best: 1671.0067893 (339)	total: 1m 32s	remaining: 2m 59s
# 340:	learn: 1705.3141905	test: 1670.7930952	best: 1670.7930952 (340)	total: 1m 32s	remaining: 2m 59s
# 341:	learn: 1705.1026393	test: 1670.5856837	best: 1670.5856837 (341)	total: 1m 33s	remaining: 2m 58s
# 342:	learn: 1704.9243848	test: 1670.4555621	best: 1670.4555621 (342)	total: 1m 33s	remaining: 2m 58s
# 343:	learn: 1704.7412892	test: 1670.2308268	best: 1670.2308268 (343)	total: 1m 33s	remaining: 2m 58s
# 344:	learn: 1704.4882996	test: 1669.9236931	best: 1669.9236931 (344)	total: 1m 33s	remaining: 2m 57s
# 345:	learn: 1704.1883477	test: 1669.6592752	best: 1669.6592752 (345)	total: 1m 33s	remaining: 2m 57s
# 346:	learn: 1703.6660849	test: 1669.2749440	best: 1669.2749440 (346)	total: 1m 34s	remaining: 2m 57s
# 347:	learn: 1703.5160712	test: 1669.2155875	best: 1669.2155875 (347)	total: 1m 34s	remaining: 2m 57s
# 348:	learn: 1703.0770283	test: 1668.8812023	best: 1668.8812023 (348)	total: 1m 34s	remaining: 2m 56s
# 349:	learn: 1702.6514316	test: 1668.5395561	best: 1668.5395561 (349)	total: 1m 34s	remaining: 2m 56s
# 350:	learn: 1702.2734322	test: 1668.1883115	best: 1668.1883115 (350)	total: 1m 35s	remaining: 2m 56s
# 351:	learn: 1701.9128541	test: 1667.9218935	best: 1667.9218935 (351)	total: 1m 35s	remaining: 2m 55s
# 352:	learn: 1701.7295493	test: 1667.7809024	best: 1667.7809024 (352)	total: 1m 35s	remaining: 2m 55s
# 353:	learn: 1701.5376609	test: 1667.5320579	best: 1667.5320579 (353)	total: 1m 36s	remaining: 2m 55s
# 354:	learn: 1701.3308775	test: 1667.3505926	best: 1667.3505926 (354)	total: 1m 36s	remaining: 2m 54s
# 355:	learn: 1700.9672059	test: 1667.0507166	best: 1667.0507166 (355)	total: 1m 36s	remaining: 2m 54s
# 356:	learn: 1700.6442488	test: 1666.8078089	best: 1666.8078089 (356)	total: 1m 36s	remaining: 2m 54s
# 357:	learn: 1700.4270918	test: 1666.5563330	best: 1666.5563330 (357)	total: 1m 36s	remaining: 2m 53s
# 358:	learn: 1700.1453763	test: 1666.2906232	best: 1666.2906232 (358)	total: 1m 37s	remaining: 2m 53s
# 359:	learn: 1699.9518514	test: 1666.1619740	best: 1666.1619740 (359)	total: 1m 37s	remaining: 2m 53s
# 360:	learn: 1699.5319081	test: 1665.8311423	best: 1665.8311423 (360)	total: 1m 37s	remaining: 2m 53s
# 361:	learn: 1699.2926430	test: 1665.5945562	best: 1665.5945562 (361)	total: 1m 37s	remaining: 2m 52s
# 362:	learn: 1698.7417584	test: 1665.1620279	best: 1665.1620279 (362)	total: 1m 38s	remaining: 2m 52s
# 363:	learn: 1698.3546117	test: 1664.9006236	best: 1664.9006236 (363)	total: 1m 38s	remaining: 2m 52s
# 364:	learn: 1697.9914302	test: 1664.6118062	best: 1664.6118062 (364)	total: 1m 38s	remaining: 2m 51s
# 365:	learn: 1697.7664406	test: 1664.4459234	best: 1664.4459234 (365)	total: 1m 38s	remaining: 2m 51s
# 366:	learn: 1697.4157342	test: 1664.1569239	best: 1664.1569239 (366)	total: 1m 39s	remaining: 2m 51s
# 367:	learn: 1697.2285106	test: 1664.0932866	best: 1664.0932866 (367)	total: 1m 39s	remaining: 2m 50s
# 368:	learn: 1697.0409406	test: 1663.9578783	best: 1663.9578783 (368)	total: 1m 39s	remaining: 2m 50s
# 369:	learn: 1696.8508885	test: 1663.7868458	best: 1663.7868458 (369)	total: 1m 40s	remaining: 2m 50s
# 370:	learn: 1696.3328237	test: 1663.3766080	best: 1663.3766080 (370)	total: 1m 40s	remaining: 2m 50s
# 371:	learn: 1696.0774432	test: 1663.1629603	best: 1663.1629603 (371)	total: 1m 40s	remaining: 2m 49s
# 372:	learn: 1695.7064909	test: 1662.8041937	best: 1662.8041937 (372)	total: 1m 40s	remaining: 2m 49s
# 373:	learn: 1695.4215769	test: 1662.4614656	best: 1662.4614656 (373)	total: 1m 41s	remaining: 2m 49s
# 374:	learn: 1695.1227532	test: 1662.2765465	best: 1662.2765465 (374)	total: 1m 41s	remaining: 2m 49s
# 375:	learn: 1694.8518459	test: 1661.9814192	best: 1661.9814192 (375)	total: 1m 41s	remaining: 2m 48s
# 376:	learn: 1694.5116394	test: 1661.8376595	best: 1661.8376595 (376)	total: 1m 41s	remaining: 2m 48s
# 377:	learn: 1694.1670917	test: 1661.6535924	best: 1661.6535924 (377)	total: 1m 42s	remaining: 2m 48s
# 378:	learn: 1693.8838707	test: 1661.4461010	best: 1661.4461010 (378)	total: 1m 42s	remaining: 2m 48s
# 379:	learn: 1693.5117050	test: 1661.1466931	best: 1661.1466931 (379)	total: 1m 42s	remaining: 2m 47s
# 380:	learn: 1693.2056665	test: 1660.9278156	best: 1660.9278156 (380)	total: 1m 43s	remaining: 2m 47s
# 381:	learn: 1693.0012509	test: 1660.7358601	best: 1660.7358601 (381)	total: 1m 43s	remaining: 2m 47s
# 382:	learn: 1692.6225518	test: 1660.4084622	best: 1660.4084622 (382)	total: 1m 43s	remaining: 2m 46s
# 383:	learn: 1692.2814067	test: 1660.1704558	best: 1660.1704558 (383)	total: 1m 43s	remaining: 2m 46s
# 384:	learn: 1691.9660470	test: 1659.9363400	best: 1659.9363400 (384)	total: 1m 44s	remaining: 2m 46s
# 385:	learn: 1691.4361387	test: 1659.5033967	best: 1659.5033967 (385)	total: 1m 44s	remaining: 2m 46s
# 386:	learn: 1691.1750004	test: 1659.2864911	best: 1659.2864911 (386)	total: 1m 44s	remaining: 2m 45s
# 387:	learn: 1690.8208274	test: 1658.9686289	best: 1658.9686289 (387)	total: 1m 45s	remaining: 2m 45s
# 388:	learn: 1690.6213258	test: 1658.7960251	best: 1658.7960251 (388)	total: 1m 45s	remaining: 2m 45s
# 389:	learn: 1690.1267248	test: 1658.3655778	best: 1658.3655778 (389)	total: 1m 45s	remaining: 2m 45s
# 390:	learn: 1689.8122702	test: 1658.0853832	best: 1658.0853832 (390)	total: 1m 45s	remaining: 2m 44s
# 391:	learn: 1689.4825004	test: 1657.8112287	best: 1657.8112287 (391)	total: 1m 46s	remaining: 2m 44s
# 392:	learn: 1689.2448341	test: 1657.6118547	best: 1657.6118547 (392)	total: 1m 46s	remaining: 2m 44s
# 393:	learn: 1688.9226641	test: 1657.4108541	best: 1657.4108541 (393)	total: 1m 46s	remaining: 2m 43s
# 394:	learn: 1688.4448116	test: 1657.0294287	best: 1657.0294287 (394)	total: 1m 46s	remaining: 2m 43s
# 395:	learn: 1688.2755779	test: 1656.8480251	best: 1656.8480251 (395)	total: 1m 47s	remaining: 2m 43s
# 396:	learn: 1687.9927276	test: 1656.6396522	best: 1656.6396522 (396)	total: 1m 47s	remaining: 2m 43s
# 397:	learn: 1687.7097206	test: 1656.4561082	best: 1656.4561082 (397)	total: 1m 47s	remaining: 2m 42s
# 398:	learn: 1687.4979132	test: 1656.2450756	best: 1656.2450756 (398)	total: 1m 47s	remaining: 2m 42s
# 399:	learn: 1687.2823063	test: 1656.0639770	best: 1656.0639770 (399)	total: 1m 48s	remaining: 2m 42s
# 400:	learn: 1687.0126241	test: 1655.8051502	best: 1655.8051502 (400)	total: 1m 48s	remaining: 2m 41s
# 401:	learn: 1686.5174959	test: 1655.4093931	best: 1655.4093931 (401)	total: 1m 48s	remaining: 2m 41s
# 402:	learn: 1686.2612776	test: 1655.2723901	best: 1655.2723901 (402)	total: 1m 48s	remaining: 2m 41s
# 403:	learn: 1685.8147336	test: 1654.9283898	best: 1654.9283898 (403)	total: 1m 49s	remaining: 2m 40s
# 404:	learn: 1685.6327553	test: 1654.7978983	best: 1654.7978983 (404)	total: 1m 49s	remaining: 2m 40s
# 405:	learn: 1685.3566499	test: 1654.5537608	best: 1654.5537608 (405)	total: 1m 49s	remaining: 2m 40s
# 406:	learn: 1684.8877672	test: 1654.3469924	best: 1654.3469924 (406)	total: 1m 49s	remaining: 2m 40s
# 407:	learn: 1684.5066421	test: 1654.0384089	best: 1654.0384089 (407)	total: 1m 50s	remaining: 2m 39s
# 408:	learn: 1684.0786181	test: 1653.6760259	best: 1653.6760259 (408)	total: 1m 50s	remaining: 2m 39s
# 409:	learn: 1683.8371692	test: 1653.5012846	best: 1653.5012846 (409)	total: 1m 50s	remaining: 2m 39s
# 410:	learn: 1683.6600311	test: 1653.3927970	best: 1653.3927970 (410)	total: 1m 50s	remaining: 2m 39s
# 411:	learn: 1683.4384798	test: 1653.2314737	best: 1653.2314737 (411)	total: 1m 51s	remaining: 2m 38s
# 412:	learn: 1683.1576429	test: 1652.9967193	best: 1652.9967193 (412)	total: 1m 51s	remaining: 2m 38s
# 413:	learn: 1682.8651340	test: 1652.7934758	best: 1652.7934758 (413)	total: 1m 51s	remaining: 2m 38s
# 414:	learn: 1682.6253315	test: 1652.5715842	best: 1652.5715842 (414)	total: 1m 51s	remaining: 2m 37s
# 415:	learn: 1682.3501285	test: 1652.3186562	best: 1652.3186562 (415)	total: 1m 52s	remaining: 2m 37s
# 416:	learn: 1682.0850324	test: 1652.0925138	best: 1652.0925138 (416)	total: 1m 52s	remaining: 2m 37s
# 417:	learn: 1681.8562751	test: 1651.9303925	best: 1651.9303925 (417)	total: 1m 52s	remaining: 2m 37s
# 418:	learn: 1681.5498710	test: 1651.6371584	best: 1651.6371584 (418)	total: 1m 52s	remaining: 2m 36s
# 419:	learn: 1681.2507387	test: 1651.3225547	best: 1651.3225547 (419)	total: 1m 53s	remaining: 2m 36s
# 420:	learn: 1680.8759354	test: 1651.0207923	best: 1651.0207923 (420)	total: 1m 53s	remaining: 2m 36s
# 421:	learn: 1680.6839181	test: 1650.8578357	best: 1650.8578357 (421)	total: 1m 53s	remaining: 2m 35s
# 422:	learn: 1680.4910209	test: 1650.6753048	best: 1650.6753048 (422)	total: 1m 54s	remaining: 2m 35s
# 423:	learn: 1680.2092310	test: 1650.5191238	best: 1650.5191238 (423)	total: 1m 54s	remaining: 2m 35s
# 424:	learn: 1679.9917819	test: 1650.3588604	best: 1650.3588604 (424)	total: 1m 54s	remaining: 2m 34s
# 425:	learn: 1679.8250293	test: 1650.1766164	best: 1650.1766164 (425)	total: 1m 54s	remaining: 2m 34s
# 426:	learn: 1679.3698596	test: 1649.8218335	best: 1649.8218335 (426)	total: 1m 55s	remaining: 2m 34s
# 427:	learn: 1679.0293292	test: 1649.5697629	best: 1649.5697629 (427)	total: 1m 55s	remaining: 2m 34s
# 428:	learn: 1678.7795934	test: 1649.4078589	best: 1649.4078589 (428)	total: 1m 55s	remaining: 2m 33s
# 429:	learn: 1678.5728272	test: 1649.2796954	best: 1649.2796954 (429)	total: 1m 55s	remaining: 2m 33s
# 430:	learn: 1678.3225903	test: 1649.0799425	best: 1649.0799425 (430)	total: 1m 55s	remaining: 2m 33s
# 431:	learn: 1677.9365135	test: 1648.7534455	best: 1648.7534455 (431)	total: 1m 56s	remaining: 2m 32s
# 432:	learn: 1677.6387505	test: 1648.5296478	best: 1648.5296478 (432)	total: 1m 56s	remaining: 2m 32s
# 433:	learn: 1677.4819245	test: 1648.4067734	best: 1648.4067734 (433)	total: 1m 56s	remaining: 2m 32s
# 434:	learn: 1677.1954564	test: 1648.2138218	best: 1648.2138218 (434)	total: 1m 57s	remaining: 2m 32s
# 435:	learn: 1676.8558056	test: 1647.9303320	best: 1647.9303320 (435)	total: 1m 57s	remaining: 2m 31s
# 436:	learn: 1676.6705961	test: 1647.8010254	best: 1647.8010254 (436)	total: 1m 57s	remaining: 2m 31s
# 437:	learn: 1676.4903970	test: 1647.6409830	best: 1647.6409830 (437)	total: 1m 57s	remaining: 2m 31s
# 438:	learn: 1676.2600733	test: 1647.4863141	best: 1647.4863141 (438)	total: 1m 58s	remaining: 2m 30s
# 439:	learn: 1676.1099864	test: 1647.3351067	best: 1647.3351067 (439)	total: 1m 58s	remaining: 2m 30s
# 440:	learn: 1675.8122519	test: 1647.1796841	best: 1647.1796841 (440)	total: 1m 58s	remaining: 2m 30s
# 441:	learn: 1675.4852513	test: 1646.9189694	best: 1646.9189694 (441)	total: 1m 58s	remaining: 2m 30s
# 442:	learn: 1675.2616983	test: 1646.7520628	best: 1646.7520628 (442)	total: 1m 59s	remaining: 2m 29s
# 443:	learn: 1675.0476706	test: 1646.6182271	best: 1646.6182271 (443)	total: 1m 59s	remaining: 2m 29s
# 444:	learn: 1674.7956666	test: 1646.4541413	best: 1646.4541413 (444)	total: 1m 59s	remaining: 2m 29s
# 445:	learn: 1674.5783565	test: 1646.2705449	best: 1646.2705449 (445)	total: 1m 59s	remaining: 2m 28s
# 446:	learn: 1674.2869323	test: 1646.0395159	best: 1646.0395159 (446)	total: 2m	remaining: 2m 28s
# 447:	learn: 1674.1157422	test: 1645.9321940	best: 1645.9321940 (447)	total: 2m	remaining: 2m 28s
# 448:	learn: 1673.6888945	test: 1645.5130462	best: 1645.5130462 (448)	total: 2m	remaining: 2m 28s
# 449:	learn: 1673.2488051	test: 1645.2258440	best: 1645.2258440 (449)	total: 2m	remaining: 2m 27s
# 450:	learn: 1673.0324483	test: 1645.0491579	best: 1645.0491579 (450)	total: 2m 1s	remaining: 2m 27s
# 451:	learn: 1672.8429095	test: 1644.8418500	best: 1644.8418500 (451)	total: 2m 1s	remaining: 2m 27s
# 452:	learn: 1672.6069833	test: 1644.6735377	best: 1644.6735377 (452)	total: 2m 1s	remaining: 2m 26s
# 453:	learn: 1672.4741817	test: 1644.5546785	best: 1644.5546785 (453)	total: 2m 1s	remaining: 2m 26s
# 454:	learn: 1672.1128783	test: 1644.2354399	best: 1644.2354399 (454)	total: 2m 2s	remaining: 2m 26s
# 455:	learn: 1671.9048348	test: 1644.0810759	best: 1644.0810759 (455)	total: 2m 2s	remaining: 2m 25s
# 456:	learn: 1671.5941798	test: 1643.8001147	best: 1643.8001147 (456)	total: 2m 2s	remaining: 2m 25s
# 457:	learn: 1671.1901195	test: 1643.4526805	best: 1643.4526805 (457)	total: 2m 2s	remaining: 2m 25s
# 458:	learn: 1670.9808654	test: 1643.3036016	best: 1643.3036016 (458)	total: 2m 3s	remaining: 2m 25s
# 459:	learn: 1670.6494009	test: 1643.1692900	best: 1643.1692900 (459)	total: 2m 3s	remaining: 2m 24s
# 460:	learn: 1670.4137582	test: 1642.9841614	best: 1642.9841614 (460)	total: 2m 3s	remaining: 2m 24s
# 461:	learn: 1670.1557928	test: 1642.7596382	best: 1642.7596382 (461)	total: 2m 3s	remaining: 2m 24s
# 462:	learn: 1669.9756481	test: 1642.6072425	best: 1642.6072425 (462)	total: 2m 4s	remaining: 2m 24s
# 463:	learn: 1669.8302735	test: 1642.4849600	best: 1642.4849600 (463)	total: 2m 4s	remaining: 2m 23s
# 464:	learn: 1669.5298333	test: 1642.2821592	best: 1642.2821592 (464)	total: 2m 4s	remaining: 2m 23s
# 465:	learn: 1669.4404599	test: 1642.2288847	best: 1642.2288847 (465)	total: 2m 5s	remaining: 2m 23s
# 466:	learn: 1669.2329145	test: 1642.0201808	best: 1642.0201808 (466)	total: 2m 5s	remaining: 2m 23s
# 467:	learn: 1668.8374369	test: 1641.7615872	best: 1641.7615872 (467)	total: 2m 5s	remaining: 2m 22s
# 468:	learn: 1668.6754516	test: 1641.6254233	best: 1641.6254233 (468)	total: 2m 5s	remaining: 2m 22s
# 469:	learn: 1668.3851023	test: 1641.4727597	best: 1641.4727597 (469)	total: 2m 6s	remaining: 2m 22s
# 470:	learn: 1668.2248419	test: 1641.3660207	best: 1641.3660207 (470)	total: 2m 6s	remaining: 2m 22s
# 471:	learn: 1668.0294254	test: 1641.2455631	best: 1641.2455631 (471)	total: 2m 6s	remaining: 2m 21s
# 472:	learn: 1667.7514652	test: 1641.1339197	best: 1641.1339197 (472)	total: 2m 6s	remaining: 2m 21s
# 473:	learn: 1667.3503197	test: 1640.7248178	best: 1640.7248178 (473)	total: 2m 7s	remaining: 2m 21s
# 474:	learn: 1667.1530093	test: 1640.5352448	best: 1640.5352448 (474)	total: 2m 7s	remaining: 2m 20s
# 475:	learn: 1667.0099766	test: 1640.4580516	best: 1640.4580516 (475)	total: 2m 7s	remaining: 2m 20s
# 476:	learn: 1666.8422746	test: 1640.3183897	best: 1640.3183897 (476)	total: 2m 7s	remaining: 2m 20s
# 477:	learn: 1666.6918400	test: 1640.2338555	best: 1640.2338555 (477)	total: 2m 8s	remaining: 2m 19s
# 478:	learn: 1666.3597552	test: 1640.0335680	best: 1640.0335680 (478)	total: 2m 8s	remaining: 2m 19s
# 479:	learn: 1666.1471311	test: 1639.8516717	best: 1639.8516717 (479)	total: 2m 8s	remaining: 2m 19s
# 480:	learn: 1666.0223760	test: 1639.7763192	best: 1639.7763192 (480)	total: 2m 8s	remaining: 2m 19s
# ...
# 840:	learn: 1499.1002403	test: 1557.1336722	best: 1557.1336722 (840)	total: 5m 45s	remaining: 1m 5s
# 841:	learn: 1499.0103985	test: 1557.0782529	best: 1557.0782529 (841)	total: 5m 46s	remaining: 1m 4s
# 842:	learn: 1498.9376389	test: 1557.0640616	best: 1557.0640616 (842)	total: 5m 46s	remaining: 1m 4s
# 843:	learn: 1498.7209241	test: 1556.9491839	best: 1556.9491839 (843)	total: 5m 46s	remaining: 1m 4s
# 844:	learn: 1498.4728240	test: 1556.8322452	best: 1556.8322452 (844)	total: 5m 47s	remaining: 1m 3s
# 845:	learn: 1498.4035844	test: 1556.7955307	best: 1556.7955307 (845)	total: 5m 47s	remaining: 1m 3s
# 846:	learn: 1498.2949384	test: 1556.7570666	best: 1556.7570666 (846)	total: 5m 48s	remaining: 1m 2s
# 847:	learn: 1498.2032779	test: 1556.7237942	best: 1556.7237942 (847)	total: 5m 48s	remaining: 1m 2s
# 848:	learn: 1498.1228971	test: 1556.7003121	best: 1556.7003121 (848)	total: 5m 49s	remaining: 1m 2s
# 849:	learn: 1498.0644238	test: 1556.7092254	best: 1556.7003121 (848)	total: 5m 49s	remaining: 1m 1s
# 850:	learn: 1497.9765061	test: 1556.6835016	best: 1556.6835016 (850)	total: 5m 49s	remaining: 1m 1s
# 851:	learn: 1497.9214712	test: 1556.6635515	best: 1556.6635515 (851)	total: 5m 50s	remaining: 1m
# 852:	learn: 1497.8336707	test: 1556.6338748	best: 1556.6338748 (852)	total: 5m 50s	remaining: 1m
# 853:	learn: 1497.6819775	test: 1556.6186010	best: 1556.6186010 (853)	total: 5m 51s	remaining: 1m
# 854:	learn: 1497.4917823	test: 1556.5758995	best: 1556.5758995 (854)	total: 5m 51s	remaining: 59.6s
# 855:	learn: 1497.4348963	test: 1556.5781136	best: 1556.5758995 (854)	total: 5m 51s	remaining: 59.2s
# 856:	learn: 1497.2825397	test: 1556.4727370	best: 1556.4727370 (856)	total: 5m 52s	remaining: 58.8s
# 857:	learn: 1497.2100735	test: 1556.4770817	best: 1556.4727370 (856)	total: 5m 52s	remaining: 58.4s
# 858:	learn: 1497.0979746	test: 1556.4577253	best: 1556.4577253 (858)	total: 5m 52s	remaining: 57.9s
# 859:	learn: 1497.0524117	test: 1556.4455958	best: 1556.4455958 (859)	total: 5m 53s	remaining: 57.5s
# 860:	learn: 1496.8699458	test: 1556.4184952	best: 1556.4184952 (860)	total: 5m 53s	remaining: 57.1s
# 861:	learn: 1496.7970002	test: 1556.3919031	best: 1556.3919031 (861)	total: 5m 54s	remaining: 56.7s
# 862:	learn: 1496.6320416	test: 1556.3483790	best: 1556.3483790 (862)	total: 5m 54s	remaining: 56.3s
# 863:	learn: 1496.5903011	test: 1556.3324898	best: 1556.3324898 (863)	total: 5m 54s	remaining: 55.9s
# 864:	learn: 1496.3814515	test: 1556.1982308	best: 1556.1982308 (864)	total: 5m 55s	remaining: 55.5s
# 865:	learn: 1496.3123693	test: 1556.1551635	best: 1556.1551635 (865)	total: 5m 55s	remaining: 55s
# 866:	learn: 1496.1983796	test: 1556.1160922	best: 1556.1160922 (866)	total: 5m 56s	remaining: 54.6s
# 867:	learn: 1496.1223891	test: 1556.0902883	best: 1556.0902883 (867)	total: 5m 56s	remaining: 54.2s
# 868:	learn: 1496.0693161	test: 1556.0700132	best: 1556.0700132 (868)	total: 5m 56s	remaining: 53.8s
# 869:	learn: 1495.9734333	test: 1556.0475347	best: 1556.0475347 (869)	total: 5m 57s	remaining: 53.4s
# 870:	learn: 1495.8599085	test: 1555.9555107	best: 1555.9555107 (870)	total: 5m 57s	remaining: 53s
# 871:	learn: 1495.7705171	test: 1555.8882297	best: 1555.8882297 (871)	total: 5m 57s	remaining: 52.5s
# 872:	learn: 1495.5886677	test: 1555.8158410	best: 1555.8158410 (872)	total: 5m 58s	remaining: 52.1s
# 873:	learn: 1495.4857122	test: 1555.7947649	best: 1555.7947649 (873)	total: 5m 58s	remaining: 51.7s
# 874:	learn: 1495.2538489	test: 1555.6536260	best: 1555.6536260 (874)	total: 5m 59s	remaining: 51.3s
# 875:	learn: 1495.1390142	test: 1555.5947564	best: 1555.5947564 (875)	total: 5m 59s	remaining: 50.9s
# 876:	learn: 1495.0469225	test: 1555.5365971	best: 1555.5365971 (876)	total: 6m	remaining: 50.5s
# 877:	learn: 1494.7923298	test: 1555.5618823	best: 1555.5365971 (876)	total: 6m	remaining: 50.1s
# 878:	learn: 1494.7352427	test: 1555.5321707	best: 1555.5321707 (878)	total: 6m	remaining: 49.7s
# 879:	learn: 1494.7130496	test: 1555.5149860	best: 1555.5149860 (879)	total: 6m 1s	remaining: 49.3s
# 880:	learn: 1494.5431576	test: 1555.4619581	best: 1555.4619581 (880)	total: 6m 1s	remaining: 48.9s
# 881:	learn: 1494.4610036	test: 1555.4614309	best: 1555.4614309 (881)	total: 6m 2s	remaining: 48.4s
# 882:	learn: 1494.3094358	test: 1555.3793307	best: 1555.3793307 (882)	total: 6m 2s	remaining: 48s
# 883:	learn: 1494.2595750	test: 1555.3009646	best: 1555.3009646 (883)	total: 6m 2s	remaining: 47.6s
# 884:	learn: 1494.2092272	test: 1555.2900377	best: 1555.2900377 (884)	total: 6m 3s	remaining: 47.2s
# 885:	learn: 1494.1231129	test: 1555.2797586	best: 1555.2797586 (885)	total: 6m 3s	remaining: 46.8s
# 886:	learn: 1494.0601978	test: 1555.2604057	best: 1555.2604057 (886)	total: 6m 3s	remaining: 46.4s
# 887:	learn: 1493.9915951	test: 1555.2387109	best: 1555.2387109 (887)	total: 6m 4s	remaining: 46s
# 888:	learn: 1493.7891106	test: 1555.1620183	best: 1555.1620183 (888)	total: 6m 4s	remaining: 45.5s
# 889:	learn: 1493.7708412	test: 1555.1608871	best: 1555.1608871 (889)	total: 6m 5s	remaining: 45.1s
# 890:	learn: 1493.7315937	test: 1555.1569299	best: 1555.1569299 (890)	total: 6m 5s	remaining: 44.7s
# 891:	learn: 1493.6327270	test: 1555.1525922	best: 1555.1525922 (891)	total: 6m 5s	remaining: 44.3s
# 892:	learn: 1493.4011498	test: 1555.0200714	best: 1555.0200714 (892)	total: 6m 6s	remaining: 43.9s
# 893:	learn: 1493.2563180	test: 1554.9253016	best: 1554.9253016 (893)	total: 6m 6s	remaining: 43.5s
# 894:	learn: 1493.1411218	test: 1554.8612755	best: 1554.8612755 (894)	total: 6m 7s	remaining: 43.1s
# 895:	learn: 1493.0820353	test: 1554.8517636	best: 1554.8517636 (895)	total: 6m 7s	remaining: 42.7s
# 896:	learn: 1492.8726674	test: 1554.7644197	best: 1554.7644197 (896)	total: 6m 8s	remaining: 42.3s
# 897:	learn: 1492.7716425	test: 1554.6934545	best: 1554.6934545 (897)	total: 6m 8s	remaining: 41.9s
# 898:	learn: 1492.6773055	test: 1554.6569740	best: 1554.6569740 (898)	total: 6m 8s	remaining: 41.5s
# 899:	learn: 1492.5557427	test: 1554.6155893	best: 1554.6155893 (899)	total: 6m 9s	remaining: 41s
# 900:	learn: 1492.4360992	test: 1554.5242994	best: 1554.5242994 (900)	total: 6m 9s	remaining: 40.6s
# 901:	learn: 1492.3938336	test: 1554.4995233	best: 1554.4995233 (901)	total: 6m 10s	remaining: 40.2s
# 902:	learn: 1492.2774282	test: 1554.4638994	best: 1554.4638994 (902)	total: 6m 10s	remaining: 39.8s
# 903:	learn: 1492.0500322	test: 1554.3935520	best: 1554.3935520 (903)	total: 6m 11s	remaining: 39.4s
# 904:	learn: 1492.0065777	test: 1554.3938416	best: 1554.3935520 (903)	total: 6m 11s	remaining: 39s
# 905:	learn: 1491.7302558	test: 1554.2857622	best: 1554.2857622 (905)	total: 6m 12s	remaining: 38.6s
# 906:	learn: 1491.6216813	test: 1554.2254899	best: 1554.2254899 (906)	total: 6m 12s	remaining: 38.2s
# 907:	learn: 1491.5517793	test: 1554.2155455	best: 1554.2155455 (907)	total: 6m 12s	remaining: 37.8s
# 908:	learn: 1491.2919230	test: 1554.1533031	best: 1554.1533031 (908)	total: 6m 13s	remaining: 37.4s
# 909:	learn: 1491.2539085	test: 1554.1411321	best: 1554.1411321 (909)	total: 6m 13s	remaining: 37s
# 910:	learn: 1491.1046979	test: 1554.0830847	best: 1554.0830847 (910)	total: 6m 14s	remaining: 36.5s
# 911:	learn: 1490.8503478	test: 1554.0465418	best: 1554.0465418 (911)	total: 6m 14s	remaining: 36.1s
# 912:	learn: 1490.7714468	test: 1554.0242481	best: 1554.0242481 (912)	total: 6m 15s	remaining: 35.7s
# 913:	learn: 1490.4368307	test: 1553.8764636	best: 1553.8764636 (913)	total: 6m 15s	remaining: 35.3s
# 914:	learn: 1490.3615238	test: 1553.8452822	best: 1553.8452822 (914)	total: 6m 15s	remaining: 34.9s
# 915:	learn: 1490.2825245	test: 1553.8157021	best: 1553.8157021 (915)	total: 6m 16s	remaining: 34.5s
# 916:	learn: 1490.1405118	test: 1553.7050831	best: 1553.7050831 (916)	total: 6m 16s	remaining: 34.1s
# 917:	learn: 1490.0481206	test: 1553.6873950	best: 1553.6873950 (917)	total: 6m 16s	remaining: 33.7s
# 918:	learn: 1489.9851265	test: 1553.6724205	best: 1553.6724205 (918)	total: 6m 17s	remaining: 33.3s
# 919:	learn: 1489.7140750	test: 1553.6085946	best: 1553.6085946 (919)	total: 6m 17s	remaining: 32.8s
# 920:	learn: 1489.6597342	test: 1553.5793305	best: 1553.5793305 (920)	total: 6m 18s	remaining: 32.4s
# 921:	learn: 1489.5774070	test: 1553.5690205	best: 1553.5690205 (921)	total: 6m 18s	remaining: 32s
# 922:	learn: 1489.3812391	test: 1553.5022642	best: 1553.5022642 (922)	total: 6m 19s	remaining: 31.6s
# 923:	learn: 1489.1260992	test: 1553.4845095	best: 1553.4845095 (923)	total: 6m 19s	remaining: 31.2s
# 924:	learn: 1489.0763654	test: 1553.4644623	best: 1553.4644623 (924)	total: 6m 20s	remaining: 30.8s
# 925:	learn: 1488.9212078	test: 1553.3757046	best: 1553.3757046 (925)	total: 6m 20s	remaining: 30.4s
# 926:	learn: 1488.8246027	test: 1553.3381037	best: 1553.3381037 (926)	total: 6m 20s	remaining: 30s
# 927:	learn: 1488.7922466	test: 1553.3265433	best: 1553.3265433 (927)	total: 6m 21s	remaining: 29.6s
# 928:	learn: 1488.6970912	test: 1553.2622343	best: 1553.2622343 (928)	total: 6m 21s	remaining: 29.2s
# 929:	learn: 1488.5783526	test: 1553.2227566	best: 1553.2227566 (929)	total: 6m 22s	remaining: 28.8s
# 930:	learn: 1488.5527180	test: 1553.1925947	best: 1553.1925947 (930)	total: 6m 22s	remaining: 28.3s
# 931:	learn: 1488.3935787	test: 1553.1241071	best: 1553.1241071 (931)	total: 6m 23s	remaining: 27.9s
# 932:	learn: 1488.3757353	test: 1553.1096877	best: 1553.1096877 (932)	total: 6m 23s	remaining: 27.5s
# 933:	learn: 1488.1640268	test: 1553.0732884	best: 1553.0732884 (933)	total: 6m 23s	remaining: 27.1s
# 934:	learn: 1487.9527918	test: 1553.0275662	best: 1553.0275662 (934)	total: 6m 24s	remaining: 26.7s
# 935:	learn: 1487.8904190	test: 1553.0127814	best: 1553.0127814 (935)	total: 6m 24s	remaining: 26.3s
# 936:	learn: 1487.6866571	test: 1552.9029261	best: 1552.9029261 (936)	total: 6m 25s	remaining: 25.9s
# 937:	learn: 1487.6784532	test: 1552.9023789	best: 1552.9023789 (937)	total: 6m 25s	remaining: 25.5s
# 938:	learn: 1487.5748225	test: 1552.9192702	best: 1552.9023789 (937)	total: 6m 25s	remaining: 25.1s
# 939:	learn: 1487.5649610	test: 1552.9108976	best: 1552.9023789 (937)	total: 6m 25s	remaining: 24.6s
# 940:	learn: 1487.3735052	test: 1552.8141486	best: 1552.8141486 (940)	total: 6m 26s	remaining: 24.2s
# 941:	learn: 1487.1782606	test: 1552.6606923	best: 1552.6606923 (941)	total: 6m 26s	remaining: 23.8s
# 942:	learn: 1487.0331285	test: 1552.6393611	best: 1552.6393611 (942)	total: 6m 27s	remaining: 23.4s
# 943:	learn: 1486.8398655	test: 1552.4917326	best: 1552.4917326 (943)	total: 6m 27s	remaining: 23s
# 944:	learn: 1486.7485627	test: 1552.4880604	best: 1552.4880604 (944)	total: 6m 27s	remaining: 22.6s
# 945:	learn: 1486.6278807	test: 1552.4608437	best: 1552.4608437 (945)	total: 6m 28s	remaining: 22.2s
# 946:	learn: 1486.4657043	test: 1552.4396092	best: 1552.4396092 (946)	total: 6m 28s	remaining: 21.8s
# 947:	learn: 1486.3866669	test: 1552.4281153	best: 1552.4281153 (947)	total: 6m 29s	remaining: 21.3s
# 948:	learn: 1486.3565285	test: 1552.4264210	best: 1552.4264210 (948)	total: 6m 29s	remaining: 20.9s
# 949:	learn: 1486.1869115	test: 1552.3467381	best: 1552.3467381 (949)	total: 6m 29s	remaining: 20.5s
# 950:	learn: 1486.0460842	test: 1552.2985924	best: 1552.2985924 (950)	total: 6m 30s	remaining: 20.1s
# 951:	learn: 1485.9623836	test: 1552.2906520	best: 1552.2906520 (951)	total: 6m 30s	remaining: 19.7s
# 952:	learn: 1485.8715090	test: 1552.2466315	best: 1552.2466315 (952)	total: 6m 31s	remaining: 19.3s
# 953:	learn: 1485.8078078	test: 1552.2208448	best: 1552.2208448 (953)	total: 6m 31s	remaining: 18.9s
# 954:	learn: 1485.6613209	test: 1552.2196944	best: 1552.2196944 (954)	total: 6m 32s	remaining: 18.5s
# 955:	learn: 1485.5050362	test: 1552.1860138	best: 1552.1860138 (955)	total: 6m 32s	remaining: 18.1s
# 956:	learn: 1485.3316901	test: 1552.0681622	best: 1552.0681622 (956)	total: 6m 32s	remaining: 17.7s
# 957:	learn: 1485.2687873	test: 1552.0731104	best: 1552.0681622 (956)	total: 6m 33s	remaining: 17.2s
# 958:	learn: 1485.1636003	test: 1551.9911510	best: 1551.9911510 (958)	total: 6m 33s	remaining: 16.8s
# 959:	learn: 1485.0076701	test: 1551.9043620	best: 1551.9043620 (959)	total: 6m 34s	remaining: 16.4s
# 960:	learn: 1484.9597386	test: 1551.8914144	best: 1551.8914144 (960)	total: 6m 34s	remaining: 16s
# 961:	learn: 1484.8317506	test: 1551.8131389	best: 1551.8131389 (961)	total: 6m 35s	remaining: 15.6s
# 962:	learn: 1484.6425089	test: 1551.7975741	best: 1551.7975741 (962)	total: 6m 35s	remaining: 15.2s
# 963:	learn: 1484.5320512	test: 1551.7211795	best: 1551.7211795 (963)	total: 6m 35s	remaining: 14.8s
# 964:	learn: 1484.3204617	test: 1551.6365519	best: 1551.6365519 (964)	total: 6m 36s	remaining: 14.4s
# 965:	learn: 1484.2185009	test: 1551.6018118	best: 1551.6018118 (965)	total: 6m 36s	remaining: 14s
# 966:	learn: 1484.1273368	test: 1551.5648139	best: 1551.5648139 (966)	total: 6m 37s	remaining: 13.6s
# 967:	learn: 1483.9972416	test: 1551.4922775	best: 1551.4922775 (967)	total: 6m 37s	remaining: 13.1s
# 968:	learn: 1483.9212736	test: 1551.4851214	best: 1551.4851214 (968)	total: 6m 38s	remaining: 12.7s
# 969:	learn: 1483.7752921	test: 1551.4533033	best: 1551.4533033 (969)	total: 6m 38s	remaining: 12.3s
# 970:	learn: 1483.5668795	test: 1551.3448187	best: 1551.3448187 (970)	total: 6m 38s	remaining: 11.9s
# 971:	learn: 1483.4151699	test: 1551.3286357	best: 1551.3286357 (971)	total: 6m 39s	remaining: 11.5s
# 972:	learn: 1483.3430794	test: 1551.3023791	best: 1551.3023791 (972)	total: 6m 39s	remaining: 11.1s
# 973:	learn: 1483.2502805	test: 1551.2823992	best: 1551.2823992 (973)	total: 6m 40s	remaining: 10.7s
# 974:	learn: 1483.0864701	test: 1551.2582077	best: 1551.2582077 (974)	total: 6m 40s	remaining: 10.3s
# 975:	learn: 1482.9363970	test: 1551.2699036	best: 1551.2582077 (974)	total: 6m 41s	remaining: 9.86s
# 976:	learn: 1482.8248593	test: 1551.2355425	best: 1551.2355425 (976)	total: 6m 41s	remaining: 9.45s
# 977:	learn: 1482.7226729	test: 1551.1856403	best: 1551.1856403 (977)	total: 6m 41s	remaining: 9.04s
# 978:	learn: 1482.5235783	test: 1551.0895210	best: 1551.0895210 (978)	total: 6m 42s	remaining: 8.63s
# 979:	learn: 1482.4084262	test: 1551.0571732	best: 1551.0571732 (979)	total: 6m 42s	remaining: 8.22s
# 980:	learn: 1482.2683693	test: 1551.0143369	best: 1551.0143369 (980)	total: 6m 43s	remaining: 7.81s
# 981:	learn: 1482.1836038	test: 1550.9915668	best: 1550.9915668 (981)	total: 6m 43s	remaining: 7.4s
# 982:	learn: 1481.9687819	test: 1550.8817887	best: 1550.8817887 (982)	total: 6m 44s	remaining: 6.99s
# 983:	learn: 1481.8953984	test: 1550.8544603	best: 1550.8544603 (983)	total: 6m 44s	remaining: 6.58s
# 984:	learn: 1481.7341268	test: 1550.8210825	best: 1550.8210825 (984)	total: 6m 45s	remaining: 6.17s
# 985:	learn: 1481.6190548	test: 1550.8312089	best: 1550.8210825 (984)	total: 6m 45s	remaining: 5.76s
# 986:	learn: 1481.5467761	test: 1550.8219163	best: 1550.8210825 (984)	total: 6m 46s	remaining: 5.35s
# 987:	learn: 1481.4257396	test: 1550.8319172	best: 1550.8210825 (984)	total: 6m 46s	remaining: 4.94s
# 988:	learn: 1481.4233307	test: 1550.8310386	best: 1550.8210825 (984)	total: 6m 46s	remaining: 4.52s
# 989:	learn: 1481.2491599	test: 1550.6880109	best: 1550.6880109 (989)	total: 6m 47s	remaining: 4.11s
# 990:	learn: 1481.0430643	test: 1550.5708773	best: 1550.5708773 (990)	total: 6m 47s	remaining: 3.7s
# 991:	learn: 1480.8338804	test: 1550.4191056	best: 1550.4191056 (991)	total: 6m 47s	remaining: 3.29s
# 992:	learn: 1480.8239497	test: 1550.4067014	best: 1550.4067014 (992)	total: 6m 48s	remaining: 2.88s
# 993:	learn: 1480.7440277	test: 1550.3754310	best: 1550.3754310 (993)	total: 6m 48s	remaining: 2.47s
# 994:	learn: 1480.6461302	test: 1550.3662168	best: 1550.3662168 (994)	total: 6m 49s	remaining: 2.06s
# 995:	learn: 1480.4913147	test: 1550.2976832	best: 1550.2976832 (995)	total: 6m 49s	remaining: 1.64s
# 996:	learn: 1480.3380750	test: 1550.2634387	best: 1550.2634387 (996)	total: 6m 49s	remaining: 1.23s
# 997:	learn: 1480.3031605	test: 1550.2693495	best: 1550.2634387 (996)	total: 6m 50s	remaining: 822ms
# 998:	learn: 1480.2957983	test: 1550.2682437	best: 1550.2634387 (996)	total: 6m 50s	remaining: 411ms
# 999:	learn: 1480.2173463	test: 1550.2539128	best: 1550.2539128 (999)	total: 6m 50s	remaining: 0us
#
# bestTest = 1550.253913
# bestIteration = 999

# %% [markdown]
# #### **Строим лучшею модель с подобранными гиперпараметрами, предсказывая валидационную выборку:**

# %%
cat_start = time.perf_counter()
cat = CatBoostRegressor(cat_features = obj_col, depth = cat_grid["params"]['depth'],
                       learning_rate = cat_grid["params"]['learning_rate'], loss_function = 'RMSE', verbose = 100)
cat.fit(xs_train,y_train)
cat_stop = time.perf_counter()
cat_time_fit = round((cat_stop - cat_start) * 1000)

cat_start = time.perf_counter()
catpred = cat.predict(xs_valid)
cat_stop = time.perf_counter()
cat_time_pred = round((cat_stop - cat_start) * 1000)

cat_std = sqrt(mse(y_valid, catpred))
# Out:
# 0:	learn: 4458.0674913	total: 485ms	remaining: 8m 4s
# 100:	learn: 1801.3944059	total: 52.6s	remaining: 7m 48s
# 200:	learn: 1665.6886920	total: 1m 41s	remaining: 6m 42s
# 300:	learn: 1617.4408308	total: 2m 27s	remaining: 5m 42s
# 400:	learn: 1584.4493413	total: 3m 14s	remaining: 4m 50s
# 500:	learn: 1556.5907995	total: 4m 4s	remaining: 4m 3s
# 600:	learn: 1536.9335646	total: 4m 53s	remaining: 3m 14s
# 700:	learn: 1520.9104714	total: 5m 42s	remaining: 2m 26s
# 800:	learn: 1506.4803654	total: 6m 31s	remaining: 1m 37s
# 900:	learn: 1493.8028193	total: 7m 20s	remaining: 48.3s
# 999:	learn: 1482.3499126	total: 8m 8s	remaining: 0us

# %% [markdown]
# ### LightGBM

# %%
forgbm = [xs_train,xs_valid,xs_test]

# %%
for m in forgbm:
    for i in obj_col:
        m[i] = m[i].astype('category')

# %%
lgbmP = {'n_estimatoros' : [100, 150, 200], 'learning_rate' : [0.1,0.2,0.4]}

# %%
lgbm = LGBMRegressor(random_state = 1667)
lgbm_par = GridSearchCV(estimator = lgbm,
                       param_grid = lgbmP, scoring = 'neg_root_mean_squared_error',
                       cv = 3,
                       verbose = 10)
lgbm_par.fit(xs_train,y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3; 1/9] START learning_rate=0.1, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 1/9] END ......learning_rate=0.1, n_estimatoros=100; total time=  12.9s
# [CV 2/3; 1/9] START learning_rate=0.1, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 1/9] END ......learning_rate=0.1, n_estimatoros=100; total time=  12.9s
# [CV 3/3; 1/9] START learning_rate=0.1, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 1/9] END ......learning_rate=0.1, n_estimatoros=100; total time=  13.4s
# [CV 1/3; 2/9] START learning_rate=0.1, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 2/9] END ......learning_rate=0.1, n_estimatoros=150; total time=  13.0s
# [CV 2/3; 2/9] START learning_rate=0.1, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 2/9] END ......learning_rate=0.1, n_estimatoros=150; total time=  18.5s
# [CV 3/3; 2/9] START learning_rate=0.1, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 2/9] END ......learning_rate=0.1, n_estimatoros=150; total time=  13.4s
# [CV 1/3; 3/9] START learning_rate=0.1, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 3/9] END ......learning_rate=0.1, n_estimatoros=200; total time=  13.1s
# [CV 2/3; 3/9] START learning_rate=0.1, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 3/9] END ......learning_rate=0.1, n_estimatoros=200; total time=  12.9s
# [CV 3/3; 3/9] START learning_rate=0.1, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 3/9] END ......learning_rate=0.1, n_estimatoros=200; total time=  13.3s
# [CV 1/3; 4/9] START learning_rate=0.2, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 4/9] END ......learning_rate=0.2, n_estimatoros=100; total time=  12.8s
# [CV 2/3; 4/9] START learning_rate=0.2, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 4/9] END ......learning_rate=0.2, n_estimatoros=100; total time=  12.6s
# [CV 3/3; 4/9] START learning_rate=0.2, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 4/9] END ......learning_rate=0.2, n_estimatoros=100; total time=  13.1s
# [CV 1/3; 5/9] START learning_rate=0.2, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 5/9] END ......learning_rate=0.2, n_estimatoros=150; total time=  12.4s
# [CV 2/3; 5/9] START learning_rate=0.2, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 5/9] END ......learning_rate=0.2, n_estimatoros=150; total time=  18.2s
# [CV 3/3; 5/9] START learning_rate=0.2, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 5/9] END ......learning_rate=0.2, n_estimatoros=150; total time=  13.1s
# [CV 1/3; 6/9] START learning_rate=0.2, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 6/9] END ......learning_rate=0.2, n_estimatoros=200; total time=  12.9s
# [CV 2/3; 6/9] START learning_rate=0.2, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 6/9] END ......learning_rate=0.2, n_estimatoros=200; total time=  13.0s
# [CV 3/3; 6/9] START learning_rate=0.2, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 6/9] END ......learning_rate=0.2, n_estimatoros=200; total time=  12.7s
# [CV 1/3; 7/9] START learning_rate=0.4, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 7/9] END ......learning_rate=0.4, n_estimatoros=100; total time=  12.4s
# [CV 2/3; 7/9] START learning_rate=0.4, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 7/9] END ......learning_rate=0.4, n_estimatoros=100; total time=  11.9s
# [CV 3/3; 7/9] START learning_rate=0.4, n_estimatoros=100........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 7/9] END ......learning_rate=0.4, n_estimatoros=100; total time=  12.0s
# [CV 1/3; 8/9] START learning_rate=0.4, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 8/9] END ......learning_rate=0.4, n_estimatoros=150; total time=  12.4s
# [CV 2/3; 8/9] START learning_rate=0.4, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 8/9] END ......learning_rate=0.4, n_estimatoros=150; total time=  17.6s
# [CV 3/3; 8/9] START learning_rate=0.4, n_estimatoros=150........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 8/9] END ......learning_rate=0.4, n_estimatoros=150; total time=  12.1s
# [CV 1/3; 9/9] START learning_rate=0.4, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 1/3; 9/9] END ......learning_rate=0.4, n_estimatoros=200; total time=  12.1s
# [CV 2/3; 9/9] START learning_rate=0.4, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 2/3; 9/9] END ......learning_rate=0.4, n_estimatoros=200; total time=  11.7s
# [CV 3/3; 9/9] START learning_rate=0.4, n_estimatoros=200........................
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# [CV 3/3; 9/9] END ......learning_rate=0.4, n_estimatoros=200; total time=  11.7s
# [LightGBM] [Warning] Unknown parameter: n_estimatoros
# GridSearchCV(cv=3, estimator=LGBMRegressor(random_state=1667),
#              param_grid={'learning_rate': [0.1, 0.2, 0.4],
#                          'n_estimatoros': [100, 150, 200]},
#              scoring='neg_root_mean_squared_error', verbose=10)

# %%
display(lgbm_par.best_params_)
# Out:
# {'learning_rate': 0.2, 'n_estimatoros': 100}

# %% [markdown]
# #### **Строим модель по найденным гиперпараметрам, предсказывая валидационную выборку:**

# %%
lgbm_start = time.perf_counter()
lgbm = LGBMRegressor(random_state = 1667, n_estimators = 100, learning_rate = 0.2).fit(xs_train,y_train, categorical_feature = obj_col)
lgbm_stop = time.perf_counter()
lgbm_time_fit = round((lgbm_stop - lgbm_start) * 1000)



lgbm_start = time.perf_counter()
lgbm_pred = lgbm.predict(xs_valid)

lgbm_stop = time.perf_counter()
lgbm_time_pred = round((lgbm_stop - lgbm_start) * 1000)


lgbm_std = sqrt(mse(y_valid, lgbm_pred))
# Out:
# /opt/conda/lib/python3.9/site-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')

# %% [markdown]
# ## Анализ моделей

# %%
d = {'RandomForestRegressor':[rfr_std,rfr_time_fit,rfr_time_predict],
    'CatBoostRegressor': [cat_std, cat_time_fit, cat_time_pred], 'LGBMRegressor':[lgbm_std, lgbm_time_fit, lgbm_time_pred]}
answer = pd.DataFrame(data = d, index = ['Validation RMSE','time fit MS','time pred MS'])

display(answer)
# Out:
#                  RandomForestRegressor  CatBoostRegressor  LGBMRegressor
# Validation RMSE            1568.355705        1584.978533    1614.764715
# time fit MS               87554.000000      495511.000000   14876.000000
# time pred MS               3438.000000        2370.000000     702.000000

# %% [markdown]
# * Дольше всех учится CatBoostRegressor - 8 минут. Быстрее всех - LGBMRegressor -около 15 секунд.
# * Cамое точное предсказание(RMSE) у модели RandomForestRegressor - 1568, Наименее точная - LGBMRegressor - 1614.
# * Быстрее всех предсказание выдает LGBMRegressor = 708ms, Дольше всех RandomForestRegressor - 3438ms

# %% [markdown]
# ## **Тестирование выбранной модели:**

# %% [markdown]
# Среди моделей выберем самую подходящую по критериям заказчика и протестируем её:

# %%
print('Результаты выбранной модели на тестовой выборке:')
lg_start = time.perf_counter()
lgbmbest = LGBMRegressor(random_state = 1667, n_estimators = 100, learning_rate = 0.2).fit(
    xs_train,y_train, categorical_feature = obj_col)
lg_stop = time.perf_counter()
print('Скорость обучения модели LGBMRegressor:')
print(best_time_fit := round((lg_stop - lg_start)* 1000))

      
print('Время предсказания модели:')
lg_start = time.perf_counter()      
test_pred = lgbmbest.predict(xs_test)
lg_stop = time.perf_counter()
print(best_time_pred := round((lg_stop - lg_start)*1000))
      



print('Итоговое значение RMSE на тестовой выборке:')
print(RMSE := sqrt(mse(y_test,test_pred)))
# Out:
# Результаты выбранной модели на тестовой выборке:
# /opt/conda/lib/python3.9/site-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# Скорость обучения модели LGBMRegressor:
# 14643
# Время предсказания модели:
# 704
# Итоговое значение RMSE на тестовой выборке:
# 1583.989976215025

# %% [markdown]
# **Для выбранной модели проведем анализ наиболее влиятельных признаков:**

# %%
gain_importance = lgbmbest.feature_importances_
dt_features = dt_features.drop(columns = ['index'])
feature_names  = dt_features.columns

gid = pd.DataFrame({'Features': feature_names, 'Gain': gain_importance})
gid = gid.sort_values(by = 'Gain', ascending = False).reset_index().drop(columns = 'index')
gid.plot(x = 'Features', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Features'>

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# 1. Была проведена первичная обработка данных, в результате которой былы:
# * Удалены признаки будущего времени, признаки не связанные с ценообразованием и признаки имеющие только одно значение.
# * Обработаны пропуски в данных.
# * Создан новый признак возраста машины.
# 2. Для качественной проверки моделей были выполнены
# * Кодирование признаков
# * Стандартизация признаков
# 3. Для сравнения моделей, с улучшением их качества были:
# * Проведен перебор по гиперпараметрам
# * С лучшими из обнаруженных гиперпараметров были замерены скорость обучения и предсказания у избранных моделей:

# %%
display(answer)
# Out:
#                  RandomForestRegressor  CatBoostRegressor  LGBMRegressor
# Validation RMSE            1568.355705        1584.978533    1614.764715
# time fit MS               87554.000000      495511.000000   14876.000000
# time pred MS               3438.000000        2370.000000     702.000000

# %% [markdown]
# 4. Для избранной модели выявлены самые влиятельные на стоимость признаки:
# - Age - возраст автомобиля
# - Power - мощность двигателя автомобиля

# %% [markdown]
# Cоответственнос с критериями, которые важны заказчику, а именно:
# * качество предсказания
# * время обучения модели
# * время предсказания модели
#
#
# **Наибиолее подходящей моделью является LightGBMRegressor(LGBMRegressor), опережающей остальные модели по показателям скорость, но незначительно(3,2% от RandomForestRegressor;  2,7% от CatBoostRegressor) отствая в точности предсказания.**
# * Гиперпараметры LGBMRegressor: n_estimators = 100, learning_rate = 0,2
